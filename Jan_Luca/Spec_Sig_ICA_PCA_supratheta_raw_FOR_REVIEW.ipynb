# %%
pip install umap-learn
# Out:
# Requirement already satisfied: umap-learn in c:\users\janlu\appdata\local\programs\python\python310\lib\site-packages (0.5.5)
# Requirement already satisfied: numpy>=1.17 in c:\users\janlu\appdata\local\programs\python\python310\lib\site-packages (from umap-learn) (1.24.4)
# Requirement already satisfied: scipy>=1.3.1 in c:\users\janlu\appdata\local\programs\python\python310\lib\site-packages (from umap-learn) (1.11.2)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\janlu\appdata\local\programs\python\python310\lib\site-packages (from umap-learn) (1.3.0)
# Requirement already satisfied: numba>=0.51.2 in c:\users\janlu\appdata\local\programs\python\python310\lib\site-packages (from umap-learn) (0.57.1)
# Requirement already satisfied: pynndescent>=0.5 in c:\users\janlu\appdata\local\programs\python\python310\lib\site-packages (from umap-learn) (0.5.11)
# Requirement already satisfied: tqdm in c:\users\janlu\appdata\local\programs\python\python310\lib\site-packages (from umap-learn) (4.66.1)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in c:\users\janlu\appdata\local\programs\python\python310\lib\site-packages (from numba>=0.51.2->umap-learn) (0.40.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\janlu\appdata\local\programs\python\python310\lib\site-packages (from pynndescent>=0.5->umap-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\janlu\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn>=0.22->umap-learn) (3.2.0)
# Requirement already satisfied: colorama in c:\users\janlu\appdata\local\programs\python\python310\lib\site-packages (from tqdm->umap-learn) (0.4.5)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.3.2 is available.
# You should consider upgrading via the 'C:\Users\janlu\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
pip install numpy scipy tqdm
# Out:
# Requirement already satisfied: numpy in c:\users\janlu\appdata\local\programs\python\python310\lib\site-packages (1.24.4)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: scipy in c:\users\janlu\appdata\local\programs\python\python310\lib\site-packages (1.11.2)
# Requirement already satisfied: tqdm in c:\users\janlu\appdata\local\programs\python\python310\lib\site-packages (4.66.1)
# Requirement already satisfied: colorama in c:\users\janlu\appdata\local\programs\python\python310\lib\site-packages (from tqdm) (0.4.5)
# WARNING: You are using pip version 22.0.4; however, version 23.3.2 is available.
# You should consider upgrading via the 'C:\Users\janlu\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import h5py
import os
import glob
import h5py
import numpy as np

from scipy.stats import zscore
from scipy.signal import find_peaks

import matplotlib.pyplot as plt

from scipy.stats import binned_statistic
from scipy.signal import find_peaks
from scipy.optimize import curve_fit 
from scipy.signal import convolve2d

#@title Dimensionality Reduction using PCA
from sklearn.decomposition import FastICA
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler


import emd.sift as sift
import emd.spectra as spectra

import pingouin as pg
import sails
import scipy.io as sio
from scipy.io import loadmat
import pandas as pd

# %%
def bin_tf_to_fpp(x, power, bin_count):
    if x.ndim == 1:  # Handle the case when x is of size (2)
        bin_ranges = np.arange(x[0], x[1], 1)
        fpp = binned_statistic(bin_ranges, power[:, x[0]:x[1]], 'mean', bins=bin_count)[0]
        fpp = np.expand_dims(fpp, axis=0)  # Add an extra dimension to match the desired output shape
    elif x.ndim == 2:  # Handle the case when x is of size (n, 2)
        fpp = []
        for i in range(x.shape[0]):
            bin_ranges = np.arange(x[i, 0], x[i, 1], 1)
            fpp_row = binned_statistic(bin_ranges, power[:, x[i, 0]:x[i, 1]], 'mean', bins=bin_count)[0]
            fpp.append(fpp_row)
        fpp = np.array(fpp)
    else:
        raise ValueError("Invalid size for x")

    return fpp

# The get_rem_states function takes in an array of sleep states and the sample rate of the data.
def get_rem_states(states, sample_rate):
    """
    Extract consecutive REM (Rapid Eye Movement) sleep states and their start
    and end times from an array of sleep states.

    Parameters:
    - states (numpy.ndarray): One-dimensional array of sleep states.
    - sample_rate (int): The sample rate of the data.

    Returns:
    numpy.ndarray: An array containing start and end times of consecutive REM
    sleep states. Each row represents a pair of start and end times.

    Note:
    - Sleep states are represented numerically. In this function, REM sleep
      states are identified by the value 5 in the 'states' array.

    Example:
    ```python
    import numpy as np

    # Example usage:
    sleep_states = np.array([1, 2, 5, 5, 5, 3, 2, 5, 5, 4, 1])
    sample_rate = 2500  # Example sample rate in Hz
    rem_states_times = get_rem_states(sleep_states, sample_rate)
    print(rem_states_times)
    ```
    """
    try:
        # Ensure the sleep states array is one-dimensional.
        states = np.squeeze(states)
        # Find the indices where the sleep state is equal to 5, indicating REM sleep.
        rem_state_indices = np.where(states == 5)[0]
        
        # Check if there are no REM states. If so, return an empty array.
        if len(rem_state_indices) == 0:
            return np.array([])
        # Calculate the changes between consecutive REM state indices.
        rem_state_changes = np.diff(rem_state_indices)
        # Find the indices where consecutive REM states are not adjacent.
        split_indices = np.where(rem_state_changes != 1)[0] + 1
        # Add indices to split consecutive REM states, including the start and end indices.
        split_indices = np.concatenate(([0], split_indices, [len(rem_state_indices)]))
        # Create an empty array to store start and end times of consecutive REM states.
        consecutive_rem_states = np.empty((len(split_indices) - 1, 2))
        # Iterate through the split indices to extract start and end times.
        for i, (start, end) in enumerate(zip(split_indices, split_indices[1:])):
            start = rem_state_indices[start] * int(sample_rate)
            end = rem_state_indices[end - 1] * int(sample_rate)
            consecutive_rem_states[i] = np.array([start, end])
        # Convert the array to a numpy array.
        ##consecutive_rem_states = np.array(consecutive_rem_states)
        # Create a mask to filter out consecutive REM states with negative duration.
        null_states_mask = np.squeeze(np.diff(consecutive_rem_states) > 0)
        consecutive_rem_states = consecutive_rem_states[null_states_mask]
        # Return the array containing start and end times of consecutive REM states.
        return consecutive_rem_states
    # Handle the case where an IndexError occurs, typically due to an empty array.
    except IndexError as e:
        print(f"An IndexError occurred in get_rem_states: {e}")
        return np.array([])  # or any default value you want


# This function computes the Morlet wavelet transform of a given signal.
# It uses the SAILS library to perform the wavelet transform.
def morlet_wt(x, sample_rate, frequencies=np.arange(1, 200, 1), n=5, mode='complex'):
    """
    Compute the Morlet wavelet transform of a given signal using the SAILS library.

    Parameters:
    - x (numpy.ndarray): The input signal.
    - sample_rate (int): The rate at which the signal is sampled.
    - frequencies (numpy.ndarray, optional): The array of frequencies at which to compute the transform
      (default is from 1 to 200 Hz).
    - n (int, optional): The number of cycles in the Morlet wavelet (default is 5).
    - mode (str, optional): The mode of the return, whether 'complex', 'power', or 'amplitude'
      (default is 'complex').
      
    Returns:
    - numpy.ndarray: The computed Morlet wavelet transform of the input signal.

    Note:
    - This function relies on the SAILS library to perform the wavelet transform.

    Example:
    ```python
    import numpy as np

    # Example usage:
    signal = np.sin(2 * np.pi * 10 * np.arange(0, 1, 1/sample_rate))
    wt_result = morlet_wt(signal, sample_rate)
    print(wt_result)
    ```
    """
    wavelet_transform = sails.wavelet.morlet(x, freqs=frequencies, sample_rate=sample_rate, ncycles=n,
                                             ret_mode=mode, normalise=None)
    # Return the computed wavelet transform.
    return wavelet_transform


# The tg_split function categorizes frequency values into three groups: sub-theta, theta, and supra-theta.
def tg_split(mask_freq, theta_range=(5, 12)):
    """
    Categorize frequency values into three groups: sub-theta, theta, and supra-theta.

    Parameters:
    - mask_freq (numpy.ndarray): An array of frequency values that you want to categorize.
    - theta_range (tuple, optional): A range of frequencies considered as the theta band
      (default is (5, 12) Hz).

    Returns:
    - tuple: A tuple containing three boolean masks representing sub-theta, theta, and supra-theta categories.

    Example:
    ```python
    import numpy as np

    # Example usage:
    freq_values = np.array([3, 8, 10, 15, 20])
    sub_mask, theta_mask, supra_mask = tg_split(freq_values)
    print("Sub-theta frequencies:", freq_values[sub_mask])
    print("Theta frequencies:", freq_values[theta_mask])
    print("Supra-theta frequencies:", freq_values[supra_mask])
    ```
    """
    # Get the lower and upper bounds of the theta range.
    lower = np.min(theta_range)
    upper = np.max(theta_range)
    # Create a boolean mask for frequencies within the theta range.
    mask_index = np.logical_and(mask_freq >= lower, mask_freq < upper)
    # Create boolean masks for frequencies below and above the theta range.
    sub_mask_index = mask_freq < lower
    supra_mask_index = mask_freq > upper
    # Assign the boolean masks to variables for each category.
    sub = sub_mask_index
    theta = mask_index
    supra = supra_mask_index
    # Return the boolean masks for sub-theta, theta, and supra-theta categories.
    return sub, theta, supra

# This function finds the indices where a signal crosses zero.
# x: The input signal.
def zero_cross(x):
    """
    Find the indices where a signal crosses zero.

    Parameters:
    - x (numpy.ndarray): The input signal.

    Returns:
    - numpy.ndarray: An array containing the indices where the input signal crosses zero.

    Example:
    ```python
    import numpy as np

    # Example usage:
    signal = np.array([1, -2, 3, -1, 0, 2, -4, 5])
    zero_cross_indices = zero_cross(signal)
    print("Zero-crossing indices:", zero_cross_indices)
    ```
    """
    # Identify where the signal goes from positive to non-positive (decay).
    decay = np.logical_and((x > 0)[1:], ~(x > 0)[:-1]).nonzero()[0]
    # Identify where the signal goes from non-positive to positive (rise).
    rise = np.logical_and((x <= 0)[1:], ~(x <= 0)[:-1]).nonzero()[0]
    # Combine the indices of rise and decay, then sort them with ascending indices.
    zero_xs = np.sort(np.append(rise, decay))
    # Return the sorted indices where the signal crosses zero.
    return zero_xs

# This function identifies the zero crossings, peaks, and troughs in a signal.
def extrema(x):
    """
    Identify the zero crossings, peaks, and troughs in a signal.

    Parameters:
    - x (numpy.ndarray): The input signal.

    Returns:
    - tuple: A tuple containing three arrays - zero-crossing indices, trough indices, and peak indices.

    Example:
    ```python
    import numpy as np

    # Example usage:
    signal = np.array([1, -2, 3, -1, 0, 2, -4, 5])
    zero_crossings, trough_indices, peak_indices = extrema(signal)
    print("Zero-crossing indices:", zero_crossings)
    print("Trough indices:", trough_indices)
    print("Peak indices:", peak_indices)
    ```
    """
    # Find the indices where the signal crosses zero.
    zero_xs = zero_cross(x)
    # Initialize empty arrays to store peak and trough indices.
    peaks = np.empty((0,)).astype(int)
    troughs = np.empty((0,)).astype(int)
    # Iterate through pairs of consecutive zero crossings.
    for t1, t2 in zip(zero_xs, zero_xs[1:]):
        # Find the index of the maximum absolute value in the current segment.
        extrema0 = np.argmax(np.abs(x[t1:t2])).astype(int) + t1
        # Check if the value at the found index is positive (peak) or non-positive (trough).
        if bool(x[extrema0] > 0):
            peaks = np.append(peaks, extrema0)
        else:
            troughs = np.append(troughs, extrema0)
    # Return the indices of zero crossings, troughs, and peaks.
    return zero_xs, troughs, peaks

# %%
#Getting spectral signatures of all rats
# Define the root folder containing '1', '3','4', '6', '9', '11', '13' folders
root_folder = r"E:\Donders"

# Define the target folders
target_folders = ['1', '3','4', '9', '11', '13']
frequency_array = np.arange(15, 140, 1)
power_list = []
fpp_list = []

for target_folder in target_folders:
    # Construct the path to the processed folders
    processed_folder = os.path.join(root_folder, target_folder, 'processed')

    # Iterate through subfolders in processed folder
    for subfolder in os.listdir(processed_folder):
        subfolder_path = os.path.join(processed_folder, subfolder)

        # Check if it's a directory
        if os.path.isdir(subfolder_path):
            # Iterate through sub-subfolders (containing datasets)
            for dataset_folder in os.listdir(subfolder_path):
                dataset_folder_path = os.path.join(subfolder_path, dataset_folder)

                # Check if it's a directory
                if os.path.isdir(dataset_folder_path):
                    # Use glob to get all .h5 files in the dataset folder
                    hdf5_files = glob.glob(os.path.join(dataset_folder_path, '*.h5'))

                    # Iterate over each .h5 file
                    for hdf5_file_path in hdf5_files:
                        # Open the HDF5 file in read mode
                        with h5py.File(hdf5_file_path, 'r') as hdf_file:
                            # Iterate over all groups in the file
                            for group_name in hdf_file.keys():
                                # Access the current group
                                # Print debugging information
                                print(f"Processing file: {hdf5_file_path}")
                                print(f"Available groups: {list(hdf_file.keys())}")
                                current_group = hdf_file[group_name]
                                
                                # Continue with your processing for the current group
                                rem_dict_keys = list(current_group.keys())
                        

                                for rem_key in rem_dict_keys:
                                    # Access the 'IMFs' key to get the Intrinsic Mode Functions
                                    imfs = current_group[rem_key]['IMFs'] 
                                    print(imfs.shape)
                                    # Identify the indices of theta frequencies in the 'IMFs' array
                                    theta_range = (5, 12)
                                    sub_theta, theta, supra_theta = tg_split(current_group[rem_key]['IMF_Frequencies'], theta_range)

                                    # Extract IMFs corresponding to theta signals and sum them up
                                    supra_theta_imfs_sum = np.sum(imfs[:, supra_theta], axis=1)
 
                                    # Access the 'wavelet_transform' key for the current REM period
                                    wavelet_transform = morlet_wt(supra_theta_imfs_sum, 2500, frequency_array, n=5, mode='amplitude')
                                    # Square each value in the matrix to get power
                                    power_matrix = np.square(np.abs(wavelet_transform))
                                    print("shape power matrix:", power_matrix.shape)
                                    # Z-score along the time axis
                                    #power = zscore(power_matrix, axis=0)
                                
                                    start_end = hdf_file[group_name][rem_key]['start-end'][:]
                                    fpp_cycles = hdf_file[group_name][rem_key]['Cycles'][:]
                                    newcycles = fpp_cycles[:, [0, -1]] - start_end[0]

                                    # Calculate mean power values for the subset of frequencies
                                    fpp_plots = bin_tf_to_fpp(newcycles, power_matrix, 19)
                                    print("shape of fpp_plots", fpp_plots.shape)
                                    
                                    # Check if fpp_plots is 1D before attempting to calculate the mean along axis 2
                                    if len(fpp_plots.shape) > 1:
                                        fpp_list.append(fpp_plots)
                                        mean_along_axis_2 = (np.mean(fpp_plots, axis=2)).T
                                        print(mean_along_axis_2.shape)
                                        power_list.append(mean_along_axis_2)
                                        print("fpp_list length:", len(fpp_list))
                                    else:
                                        # Handle the case where fpp_plots is 1D (e.g., if there's an issue with the data)
                                        print("Error: Dimensions of fpp_plots are too small.")
combined_fpp = np.concatenate(fpp_list, axis=0)
print("combined_fpp shape is", combined_fpp.shape)
# Replace the original list comprehension for filtered_power_list
filtered_power_list = [arr for arr in power_list if len(arr.shape) > 0]

# Concatenate the filtered arrays
power_array = np.concatenate(filtered_power_list, axis=1)
print(power_array.shape)

# Calculate the mean power across all cycles
spectral_signature_mean = np.mean(power_array, axis=1)

# Calculate the standard deviation across all cycles (instead of standard error of the mean)
spectral_signature_std = np.std(power_array, axis=1)

# Plot the mean power across all cycles
plt.plot(frequency_array, spectral_signature_mean, linestyle='-', color='blue', label='Mean Spectral Signature')

# Fill the area between mean - std and mean + std with a translucent color
plt.fill_between(frequency_array, spectral_signature_mean - spectral_signature_std, spectral_signature_mean + spectral_signature_std, color='lightblue', alpha=0.3, label='Standard Deviation of Spectral Signature')

plt.xlabel('Frequency[Hz]')
plt.ylabel('Power')
plt.title(f'Spectral signature z-scored - Rat: {target_folders}')
# Place the legend outside of the plot
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.show()
# Out:
# Processing file: E:\Donders\1\processed\CN\post_trial1_2017-09-28_11-30-59\post_trial1_2017-09-28_11-30-59_REM_dict.h5
# Available groups: ['post_trial1_2017-09-28_11-30-59']
# (212501, 6)
# shape power matrix: (125, 212501)
# shape of fpp_plots (610, 125, 19)
# (125, 610)
# fpp_list length: 1
# Processing file: E:\Donders\1\processed\CN\post_trial2_2017-09-28_12-21-41\post_trial2_2017-09-28_12-21-41_REM_dict.h5
# Available groups: ['post_trial2_2017-09-28_12-21-41']
# (157501, 6)
# shape power matrix: (125, 157501)
# shape of fpp_plots (416, 125, 19)
# (125, 416)
# fpp_list length: 2
# Processing file: E:\Donders\1\processed\CN\post_trial3_2017-09-28_13-12-53\post_trial3_2017-09-28_13-12-53_REM_dict.h5
# Available groups: ['post_trial3_2017-09-28_13-12-53']
# (52501, 6)
# shape power matrix: (125, 52501)
# shape of fpp_plots (147, 125, 19)
# (125, 147)
# fpp_list length: 3
# (145001, 6)
# shape power matrix: (125, 145001)
# shape of fpp_plots (388, 125, 19)
# (125, 388)
# fpp_list length: 4
# (47501, 6)
# shape power matrix: (125, 47501)
# shape of fpp_plots (132, 125, 19)
# (125, 132)
# fpp_list length: 5
# (75001, 6)
# shape power matrix: (125, 75001)
# shape of fpp_plots (208, 125, 19)
# (125, 208)
# fpp_list length: 6
# (55001, 6)
# shape power matrix: (125, 55001)
# shape of fpp_plots (148, 125, 19)
# (125, 148)
# fpp_list length: 7
# (202501, 6)
# shape power matrix: (125, 202501)
# shape of fpp_plots (574, 125, 19)
# (125, 574)
# fpp_list length: 8
# (117501, 6)
# shape power matrix: (125, 117501)
# shape of fpp_plots (329, 125, 19)
# (125, 329)
# fpp_list length: 9
# Processing file: E:\Donders\1\processed\CN\post_trial4_2017-09-28_14-03-38\post_trial4_2017-09-28_14-03-38_REM_dict.h5
# Available groups: ['post_trial4_2017-09-28_14-03-38']
# (275001, 6)
# shape power matrix: (125, 275001)
# shape of fpp_plots (772, 125, 19)
# (125, 772)
# fpp_list length: 10
# (82501, 6)
# shape power matrix: (125, 82501)
# shape of fpp_plots (226, 125, 19)
# (125, 226)
# fpp_list length: 11
# Processing file: E:\Donders\1\processed\CN\post_trial5_2017-09-28_14-55-18\post_trial5_2017-09-28_14-55-18_REM_dict.h5
# Available groups: ['post_trial5_2017-09-28_14-55-18']
# (230001, 6)
# shape power matrix: (125, 230001)
# shape of fpp_plots (654, 125, 19)
# (125, 654)
# fpp_list length: 12
# (280001, 6)
# shape power matrix: (125, 280001)
# shape of fpp_plots (788, 125, 19)
# (125, 788)
# fpp_list length: 13
# (227501, 6)
# shape power matrix: (125, 227501)
# shape of fpp_plots (600, 125, 19)
# (125, 600)
# fpp_list length: 14
# (277501, 6)
# shape power matrix: (125, 277501)
# shape of fpp_plots (787, 125, 19)
# (125, 787)
# fpp_list length: 15
# (85001, 6)
# shape power matrix: (125, 85001)
# shape of fpp_plots (238, 125, 19)
# (125, 238)
# fpp_list length: 16
# (50001, 6)
# shape power matrix: (125, 50001)
# shape of fpp_plots (124, 125, 19)
# (125, 124)
# fpp_list length: 17
# (255001, 6)
# shape power matrix: (125, 255001)
# shape of fpp_plots (734, 125, 19)
# (125, 734)
# fpp_list length: 18
# (140001, 6)
# shape power matrix: (125, 140001)
# shape of fpp_plots (377, 125, 19)
# (125, 377)
# fpp_list length: 19
# (367501, 6)
# shape power matrix: (125, 367501)
# shape of fpp_plots (1028, 125, 19)
# (125, 1028)
# fpp_list length: 20
# (252501, 6)
# shape power matrix: (125, 252501)
# shape of fpp_plots (675, 125, 19)
# (125, 675)
# fpp_list length: 21
# (127501, 6)
# shape power matrix: (125, 127501)
# shape of fpp_plots (341, 125, 19)
# (125, 341)
# fpp_list length: 22
# (267501, 6)
# shape power matrix: (125, 267501)
# shape of fpp_plots (729, 125, 19)
# (125, 729)
# fpp_list length: 23
# (125001, 6)
# shape power matrix: (125, 125001)
# shape of fpp_plots (357, 125, 19)
# (125, 357)
# fpp_list length: 24
# (62501, 6)
# shape power matrix: (125, 62501)
# shape of fpp_plots (176, 125, 19)
# (125, 176)
# fpp_list length: 25
# (25001, 6)
# shape power matrix: (125, 25001)
# shape of fpp_plots (72, 125, 19)
# (125, 72)
# fpp_list length: 26
# (357501, 6)
# shape power matrix: (125, 357501)
# shape of fpp_plots (963, 125, 19)
# (125, 963)
# fpp_list length: 27
# Processing file: E:\Donders\1\processed\CN\presleep_2017-09-28_10-38-28\presleep_2017-09-28_10-38-28_REM_dict.h5
# Available groups: ['presleep_2017-09-28_10-38-28']
# Processing file: E:\Donders\1\processed\HC\post_trial1_2017-09-27_10-56-20\post_trial1_2017-09-27_10-56-20_REM_dict.h5
# Available groups: ['post_trial1_2017-09-27_10-56-20']
# (175001, 6)
# shape power matrix: (125, 175001)
# shape of fpp_plots (504, 125, 19)
# (125, 504)
# fpp_list length: 28
# Processing file: E:\Donders\1\processed\HC\post_trial2_2017-09-27_11-46-56\post_trial2_2017-09-27_11-46-56_REM_dict.h5
# Available groups: ['post_trial2_2017-09-27_11-46-56']
# (162501, 6)
# shape power matrix: (125, 162501)
# shape of fpp_plots (463, 125, 19)
# (125, 463)
# fpp_list length: 29
# (170001, 6)
# shape power matrix: (125, 170001)
# shape of fpp_plots (497, 125, 19)
# (125, 497)
# fpp_list length: 30
# (27501, 6)
# shape power matrix: (125, 27501)
# shape of fpp_plots (74, 125, 19)
# (125, 74)
# fpp_list length: 31
# Processing file: E:\Donders\1\processed\HC\post_trial3_2017-09-27_12-37-12\post_trial3_2017-09-27_12-37-12_REM_dict.h5
# Available groups: ['post_trial3_2017-09-27_12-37-12']
# (87501, 6)
# shape power matrix: (125, 87501)
# shape of fpp_plots (256, 125, 19)
# (125, 256)
# fpp_list length: 32
# (155001, 6)
# shape power matrix: (125, 155001)
# shape of fpp_plots (426, 125, 19)
# (125, 426)
# fpp_list length: 33
# (77501, 6)
# shape power matrix: (125, 77501)
# shape of fpp_plots (212, 125, 19)
# (125, 212)
# fpp_list length: 34
# (65001, 6)
# shape power matrix: (125, 65001)
# shape of fpp_plots (199, 125, 19)
# (125, 199)
# fpp_list length: 35
# Processing file: E:\Donders\1\processed\HC\post_trial4_2017-09-27_13-27-32\post_trial4_2017-09-27_13-27-32_REM_dict.h5
# Available groups: ['post_trial4_2017-09-27_13-27-32']
# (182501, 6)
# shape power matrix: (125, 182501)
# shape of fpp_plots (538, 125, 19)
# (125, 538)
# fpp_list length: 36
# (177501, 6)
# shape power matrix: (125, 177501)
# shape of fpp_plots (509, 125, 19)
# (125, 509)
# fpp_list length: 37
# (97501, 6)
# shape power matrix: (125, 97501)
# shape of fpp_plots (268, 125, 19)
# (125, 268)
# fpp_list length: 38
# Processing file: E:\Donders\1\processed\HC\post_trial5_2017-09-27_14-18-24\post_trial5_2017-09-27_14-18-24_REM_dict.h5
# Available groups: ['post_trial5_2017-09-27_14-18-24']
# (335001, 6)
# shape power matrix: (125, 335001)
# shape of fpp_plots (949, 125, 19)
# (125, 949)
# fpp_list length: 39
# (207501, 6)
# shape power matrix: (125, 207501)
# shape of fpp_plots (565, 125, 19)
# (125, 565)
# fpp_list length: 40
# (245001, 6)
# shape power matrix: (125, 245001)
# shape of fpp_plots (688, 125, 19)
# (125, 688)
# fpp_list length: 41
# (62501, 6)
# shape power matrix: (125, 62501)
# shape of fpp_plots (180, 125, 19)
# (125, 180)
# fpp_list length: 42
# (115001, 6)
# shape power matrix: (125, 115001)
# shape of fpp_plots (322, 125, 19)
# (125, 322)
# fpp_list length: 43
# (115001, 6)
# shape power matrix: (125, 115001)
# shape of fpp_plots (339, 125, 19)
# (125, 339)
# fpp_list length: 44
# (310001, 6)
# shape power matrix: (125, 310001)
# shape of fpp_plots (863, 125, 19)
# (125, 863)
# fpp_list length: 45
# (310001, 6)
# shape power matrix: (125, 310001)
# shape of fpp_plots (883, 125, 19)
# (125, 883)
# fpp_list length: 46
# (207501, 6)
# shape power matrix: (125, 207501)
# shape of fpp_plots (602, 125, 19)
# (125, 602)
# fpp_list length: 47
# Processing file: E:\Donders\1\processed\HC\presleep_2017-09-27_10-02-30\presleep_2017-09-27_10-02-30_REM_dict.h5
# Available groups: ['presleep_2017-09-27_10-02-30']
# Processing file: E:\Donders\1\processed\OD\post_trial1_2017-09-21_11-06-43\post_trial1_2017-09-21_11-06-43_REM_dict.h5
# Available groups: ['post_trial1_2017-09-21_11-06-43']
# (285001, 6)
# shape power matrix: (125, 285001)
# shape of fpp_plots (809, 125, 19)
# (125, 809)
# fpp_list length: 48
# (170001, 6)
# shape power matrix: (125, 170001)
# shape of fpp_plots (489, 125, 19)
# (125, 489)
# fpp_list length: 49
# Processing file: E:\Donders\1\processed\OD\post_trial2_2017-09-21_11-57-34\post_trial2_2017-09-21_11-57-34_REM_dict.h5
# Available groups: ['post_trial2_2017-09-21_11-57-34']
# (270001, 6)
# shape power matrix: (125, 270001)
# shape of fpp_plots (755, 125, 19)
# (125, 755)
# fpp_list length: 50
# (100001, 6)
# shape power matrix: (125, 100001)
# shape of fpp_plots (249, 125, 19)
# (125, 249)
# fpp_list length: 51
# Processing file: E:\Donders\1\processed\OD\post_trial3_2017-09-21_12-48-10\post_trial3_2017-09-21_12-48-10_REM_dict.h5
# Available groups: ['post_trial3_2017-09-21_12-48-10']
# (277501, 6)
# shape power matrix: (125, 277501)
# shape of fpp_plots (770, 125, 19)
# (125, 770)
# fpp_list length: 52
# (467501, 6)
# shape power matrix: (125, 467501)
# shape of fpp_plots (1366, 125, 19)
# (125, 1366)
# fpp_list length: 53
# (220001, 6)
# shape power matrix: (125, 220001)
# shape of fpp_plots (633, 125, 19)
# (125, 633)
# fpp_list length: 54
# (440001, 6)
# shape power matrix: (125, 440001)
# shape of fpp_plots (1269, 125, 19)
# (125, 1269)
# fpp_list length: 55
# (42501, 6)
# shape power matrix: (125, 42501)
# shape of fpp_plots (114, 125, 19)
# (125, 114)
# fpp_list length: 56
# Processing file: E:\Donders\1\processed\OD\post_trial4_2017-09-21_13-40-22\post_trial4_2017-09-21_13-40-22_REM_dict.h5
# Available groups: ['post_trial4_2017-09-21_13-40-22']
# (465001, 6)
# shape power matrix: (125, 465001)
# shape of fpp_plots (1292, 125, 19)
# (125, 1292)
# fpp_list length: 57
# (527501, 6)
# shape power matrix: (125, 527501)
# shape of fpp_plots (1452, 125, 19)
# (125, 1452)
# fpp_list length: 58
# Processing file: E:\Donders\1\processed\OD\post_trial5_2017-09-21_14-31-51\post_trial5_2017-09-21_14-31-51_REM_dict.h5
# Available groups: ['post_trial5_2017-09-21_14-31-51']
# (602501, 6)
# shape power matrix: (125, 602501)
# shape of fpp_plots (1592, 125, 19)
# (125, 1592)
# fpp_list length: 59
# (122501, 6)
# shape power matrix: (125, 122501)
# shape of fpp_plots (368, 125, 19)
# (125, 368)
# fpp_list length: 60
# (40001, 6)
# shape power matrix: (125, 40001)
# shape of fpp_plots (96, 125, 19)
# (125, 96)
# fpp_list length: 61
# (80001, 6)
# shape power matrix: (125, 80001)
# shape of fpp_plots (211, 125, 19)
# (125, 211)
# fpp_list length: 62
# (260001, 6)
# shape power matrix: (125, 260001)
# shape of fpp_plots (735, 125, 19)
# (125, 735)
# fpp_list length: 63
# (702501, 6)
# shape power matrix: (125, 702501)
# shape of fpp_plots (1761, 125, 19)
# (125, 1761)
# fpp_list length: 64
# (170001, 6)
# shape power matrix: (125, 170001)
# shape of fpp_plots (453, 125, 19)
# (125, 453)
# fpp_list length: 65
# (197501, 6)
# shape power matrix: (125, 197501)
# shape of fpp_plots (566, 125, 19)
# (125, 566)
# fpp_list length: 66
# (200001, 6)
# shape power matrix: (125, 200001)
# shape of fpp_plots (539, 125, 19)
# (125, 539)
# fpp_list length: 67
# (117501, 6)
# shape power matrix: (125, 117501)
# shape of fpp_plots (335, 125, 19)
# (125, 335)
# fpp_list length: 68
# (7501, 6)
# shape power matrix: (125, 7501)
# shape of fpp_plots (20, 125, 19)
# (125, 20)
# fpp_list length: 69
# (715001, 6)
# shape power matrix: (125, 715001)
# shape of fpp_plots (1946, 125, 19)
# (125, 1946)
# fpp_list length: 70
# (87501, 6)
# shape power matrix: (125, 87501)
# shape of fpp_plots (253, 125, 19)
# (125, 253)
# fpp_list length: 71
# (417501, 6)
# shape power matrix: (125, 417501)
# shape of fpp_plots (1164, 125, 19)
# (125, 1164)
# fpp_list length: 72
# Processing file: E:\Donders\1\processed\OD\presleep_2017-09-21_10-12-40\presleep_2017-09-21_10-12-40_REM_dict.h5
# Available groups: ['presleep_2017-09-21_10-12-40']
# Processing file: E:\Donders\1\processed\study_day_2_OR\post_trial1_2017-09-25_11-26-43\post_trial1_2017-09-25_11-26-43_REM_dict.h5
# Available groups: ['post_trial1_2017-09-25_11-26-43']
# (157501, 6)
# shape power matrix: (125, 157501)
# shape of fpp_plots (443, 125, 19)
# (125, 443)
# fpp_list length: 73
# (157501, 6)
# shape power matrix: (125, 157501)
# shape of fpp_plots (436, 125, 19)
# (125, 436)
# fpp_list length: 74
# Processing file: E:\Donders\1\processed\study_day_2_OR\post_trial2_2017-09-25_12-17-49\post_trial2_2017-09-25_12-17-49_REM_dict.h5
# Available groups: ['post_trial2_2017-09-25_12-17-49']
# (15001, 6)
# shape power matrix: (125, 15001)
# shape of fpp_plots (43, 125, 19)
# (125, 43)
# fpp_list length: 75
# (5001, 6)
# shape power matrix: (125, 5001)
# shape of fpp_plots (12, 125, 19)
# (125, 12)
# fpp_list length: 76
# (20001, 6)
# shape power matrix: (125, 20001)
# shape of fpp_plots (53, 125, 19)
# (125, 53)
# fpp_list length: 77
# (27501, 6)
# shape power matrix: (125, 27501)
# shape of fpp_plots (69, 125, 19)
# (125, 69)
# fpp_list length: 78
# (15001, 6)
# shape power matrix: (125, 15001)
# shape of fpp_plots (41, 125, 19)
# (125, 41)
# fpp_list length: 79
# Processing file: E:\Donders\1\processed\study_day_2_OR\post_trial3_2017-09-25_13-08-52\post_trial3_2017-09-25_13-08-52_REM_dict.h5
# Available groups: ['post_trial3_2017-09-25_13-08-52']
# (150001, 6)
# shape power matrix: (125, 150001)
# shape of fpp_plots (411, 125, 19)
# (125, 411)
# fpp_list length: 80
# (47501, 6)
# shape power matrix: (125, 47501)
# shape of fpp_plots (135, 125, 19)
# (125, 135)
# fpp_list length: 81
# (245001, 6)
# shape power matrix: (125, 245001)
# shape of fpp_plots (715, 125, 19)
# (125, 715)
# fpp_list length: 82
# Processing file: E:\Donders\1\processed\study_day_2_OR\post_trial4_2017-09-25_14-01-00\post_trial4_2017-09-25_14-01-00_REM_dict.h5
# Available groups: ['post_trial4_2017-09-25_14-01-00']
# (310001, 6)
# shape power matrix: (125, 310001)
# shape of fpp_plots (897, 125, 19)
# (125, 897)
# fpp_list length: 83
# (62501, 6)
# shape power matrix: (125, 62501)
# shape of fpp_plots (178, 125, 19)
# (125, 178)
# fpp_list length: 84
# (275001, 6)
# shape power matrix: (125, 275001)
# shape of fpp_plots (755, 125, 19)
# (125, 755)
# fpp_list length: 85
# (92501, 6)
# shape power matrix: (125, 92501)
# shape of fpp_plots (257, 125, 19)
# (125, 257)
# fpp_list length: 86
# (255001, 6)
# shape power matrix: (125, 255001)
# shape of fpp_plots (727, 125, 19)
# (125, 727)
# fpp_list length: 87
# (105001, 6)
# shape power matrix: (125, 105001)
# shape of fpp_plots (289, 125, 19)
# (125, 289)
# fpp_list length: 88
# Processing file: E:\Donders\1\processed\study_day_2_OR\post_trial5_2017-09-25_14-52-04\post_trial5_2017-09-25_14-52-04_REM_dict.h5
# Available groups: ['post_trial5_2017-09-25_14-52-04']
# (172501, 6)
# shape power matrix: (125, 172501)
# shape of fpp_plots (468, 125, 19)
# (125, 468)
# fpp_list length: 89
# (197501, 6)
# shape power matrix: (125, 197501)
# shape of fpp_plots (496, 125, 19)
# (125, 496)
# fpp_list length: 90
# (62501, 6)
# shape power matrix: (125, 62501)
# shape of fpp_plots (122, 125, 19)
# (125, 122)
# fpp_list length: 91
# (22501, 6)
# shape power matrix: (125, 22501)
# shape of fpp_plots (22, 125, 19)
# (125, 22)
# fpp_list length: 92
# (117501, 6)
# shape power matrix: (125, 117501)
# shape of fpp_plots (321, 125, 19)
# (125, 321)
# fpp_list length: 93
# (7501, 6)
# shape power matrix: (125, 7501)
# shape of fpp_plots (11, 125, 19)
# (125, 11)
# fpp_list length: 94
# (2972501, 6)
# shape power matrix: (125, 2972501)
# shape of fpp_plots (4727, 125, 19)
# (125, 4727)
# fpp_list length: 95
# (282501, 6)
# shape power matrix: (125, 282501)
# shape of fpp_plots (756, 125, 19)
# (125, 756)
# fpp_list length: 96
# (40001, 6)
# shape power matrix: (125, 40001)
# shape of fpp_plots (104, 125, 19)
# (125, 104)
# fpp_list length: 97
# (122501, 6)
# shape power matrix: (125, 122501)
# shape of fpp_plots (315, 125, 19)
# (125, 315)
# fpp_list length: 98
# (147501, 6)
# shape power matrix: (125, 147501)
# shape of fpp_plots (394, 125, 19)
# (125, 394)
# fpp_list length: 99
# (405001, 6)
# shape power matrix: (125, 405001)
# shape of fpp_plots (1109, 125, 19)
# (125, 1109)
# fpp_list length: 100
# (122501, 6)
# shape power matrix: (125, 122501)
# shape of fpp_plots (313, 125, 19)
# (125, 313)
# fpp_list length: 101
# (240001, 6)
# shape power matrix: (125, 240001)
# shape of fpp_plots (632, 125, 19)
# (125, 632)
# fpp_list length: 102
# (335001, 6)
# shape power matrix: (125, 335001)
# shape of fpp_plots (905, 125, 19)
# (125, 905)
# fpp_list length: 103
# Processing file: E:\Donders\1\processed\study_day_2_OR\presleep_2017-09-25_10-30-34\presleep_2017-09-25_10-30-34_REM_dict.h5
# Available groups: ['presleep_2017-09-25_10-30-34']
# Processing file: E:\Donders\1\processed\study_day_5_OR_N\post_trial1_2017-10-03_11-05-10\post_trial1_2017-10-03_11-05-10_REM_dict.h5
# Available groups: ['post_trial1_2017-10-03_11-05-10']
# Processing file: E:\Donders\1\processed\study_day_5_OR_N\post_trial2_2017-10-03_12-00-20\post_trial2_2017-10-03_12-00-20_REM_dict.h5
# Available groups: ['post_trial2_2017-10-03_12-00-20']
# Processing file: E:\Donders\1\processed\study_day_5_OR_N\post_trial3_2017-10-03_12-53-38\post_trial3_2017-10-03_12-53-38_REM_dict.h5
# Available groups: ['post_trial3_2017-10-03_12-53-38']
# Processing file: E:\Donders\1\processed\study_day_5_OR_N\post_trial4_2017-10-03_13-45-43\post_trial4_2017-10-03_13-45-43_REM_dict.h5
# Available groups: ['post_trial4_2017-10-03_13-45-43']
# (150001, 6)
# shape power matrix: (125, 150001)
# shape of fpp_plots (399, 125, 19)
# (125, 399)
# fpp_list length: 104
# Processing file: E:\Donders\1\processed\study_day_5_OR_N\post_trial5_2017-10-03_15-12-56\post_trial5_2017-10-03_15-12-56_REM_dict.h5
# Available groups: ['post_trial5_2017-10-03_15-12-56']
# (50001, 6)
# shape power matrix: (125, 50001)
# shape of fpp_plots (134, 125, 19)
# (125, 134)
# fpp_list length: 105
# (412501, 6)
# shape power matrix: (125, 412501)
# shape of fpp_plots (1147, 125, 19)
# (125, 1147)
# fpp_list length: 106
# (297501, 6)
# shape power matrix: (125, 297501)
# shape of fpp_plots (863, 125, 19)
# (125, 863)
# fpp_list length: 107
# (195001, 6)
# shape power matrix: (125, 195001)
# shape of fpp_plots (425, 125, 19)
# (125, 425)
# fpp_list length: 108
# (447501, 6)
# shape power matrix: (125, 447501)
# shape of fpp_plots (1255, 125, 19)
# (125, 1255)
# fpp_list length: 109
# (45001, 6)
# shape power matrix: (125, 45001)
# shape of fpp_plots (120, 125, 19)
# (125, 120)
# fpp_list length: 110
# (190001, 6)
# shape power matrix: (125, 190001)
# shape of fpp_plots (531, 125, 19)
# (125, 531)
# fpp_list length: 111
# (105001, 6)
# shape power matrix: (125, 105001)
# shape of fpp_plots (309, 125, 19)
# (125, 309)
# fpp_list length: 112
# (337501, 6)
# shape power matrix: (125, 337501)
# shape of fpp_plots (981, 125, 19)
# (125, 981)
# fpp_list length: 113
# (102501, 6)
# shape power matrix: (125, 102501)
# shape of fpp_plots (314, 125, 19)
# (125, 314)
# fpp_list length: 114
# (12501, 6)
# shape power matrix: (125, 12501)
# shape of fpp_plots (32, 125, 19)
# (125, 32)
# fpp_list length: 115
# (340001, 6)
# shape power matrix: (125, 340001)
# shape of fpp_plots (949, 125, 19)
# (125, 949)
# fpp_list length: 116
# (377501, 6)
# shape power matrix: (125, 377501)
# shape of fpp_plots (986, 125, 19)
# (125, 986)
# fpp_list length: 117
# (32501, 6)
# shape power matrix: (125, 32501)
# shape of fpp_plots (87, 125, 19)
# (125, 87)
# fpp_list length: 118
# (10001, 6)
# shape power matrix: (125, 10001)
# shape of fpp_plots (24, 125, 19)
# (125, 24)
# fpp_list length: 119
# Processing file: E:\Donders\1\processed\study_day_5_OR_N\presleep_2017-10-03_10-12-30\presleep_2017-10-03_10-12-30_REM_dict.h5
# Available groups: ['presleep_2017-10-03_10-12-30']
# Processing file: E:\Donders\3\processed\CN\post_trial1_2017-11-13_10-54-15\post_trial1_2017-11-13_10-54-15_REM_dict.h5
# Available groups: ['post_trial1_2017-11-13_10-54-15']
# Processing file: E:\Donders\3\processed\CN\post_trial2_2017-11-13_11-45-00\post_trial2_2017-11-13_11-45-00_REM_dict.h5
# Available groups: ['post_trial2_2017-11-13_11-45-00']
# Processing file: E:\Donders\3\processed\CN\post_trial3_2017-11-13_12-35-45\post_trial3_2017-11-13_12-35-45_REM_dict.h5
# Available groups: ['post_trial3_2017-11-13_12-35-45']
# Processing file: E:\Donders\3\processed\CN\post_trial4_2017-11-13_13-26-21\post_trial4_2017-11-13_13-26-21_REM_dict.h5
# Available groups: ['post_trial4_2017-11-13_13-26-21']
# (77501, 6)
# shape power matrix: (125, 77501)
# shape of fpp_plots (188, 125, 19)
# (125, 188)
# fpp_list length: 120
# (252501, 6)
# shape power matrix: (125, 252501)
# shape of fpp_plots (541, 125, 19)
# (125, 541)
# fpp_list length: 121
# (150001, 6)
# shape power matrix: (125, 150001)
# shape of fpp_plots (275, 125, 19)
# (125, 275)
# fpp_list length: 122
# (175001, 6)
# shape power matrix: (125, 175001)
# shape of fpp_plots (352, 125, 19)
# (125, 352)
# fpp_list length: 123
# Processing file: E:\Donders\3\processed\CN\post_trial5_2017-11-13_14-17-00\post_trial5_2017-11-13_14-17-00_REM_dict.h5
# Available groups: ['post_trial5_2017-11-13_14-17-00']
# (395001, 6)
# shape power matrix: (125, 395001)
# shape of fpp_plots (663, 125, 19)
# (125, 663)
# fpp_list length: 124
# (260001, 6)
# shape power matrix: (125, 260001)
# shape of fpp_plots (663, 125, 19)
# (125, 663)
# fpp_list length: 125
# (190001, 6)
# shape power matrix: (125, 190001)
# shape of fpp_plots (381, 125, 19)
# (125, 381)
# fpp_list length: 126
# (67501, 6)
# shape power matrix: (125, 67501)
# shape of fpp_plots (179, 125, 19)
# (125, 179)
# fpp_list length: 127
# (192501, 6)
# shape power matrix: (125, 192501)
# shape of fpp_plots (387, 125, 19)
# (125, 387)
# fpp_list length: 128
# (150001, 6)
# shape power matrix: (125, 150001)
# shape of fpp_plots (346, 125, 19)
# (125, 346)
# fpp_list length: 129
# (315001, 6)
# shape power matrix: (125, 315001)
# shape of fpp_plots (677, 125, 19)
# (125, 677)
# fpp_list length: 130
# (465001, 6)
# shape power matrix: (125, 465001)
# shape of fpp_plots (1180, 125, 19)
# (125, 1180)
# fpp_list length: 131
# (290001, 6)
# shape power matrix: (125, 290001)
# shape of fpp_plots (762, 125, 19)
# (125, 762)
# fpp_list length: 132
# (177501, 6)
# shape power matrix: (125, 177501)
# shape of fpp_plots (454, 125, 19)
# (125, 454)
# fpp_list length: 133
# (410001, 6)
# shape power matrix: (125, 410001)
# shape of fpp_plots (1021, 125, 19)
# (125, 1021)
# fpp_list length: 134
# (287501, 6)
# shape power matrix: (125, 287501)
# shape of fpp_plots (728, 125, 19)
# (125, 728)
# fpp_list length: 135
# Processing file: E:\Donders\3\processed\CN\presleep_2017-11-13_10-03-32\presleep_2017-11-13_10-03-32_REM_dict.h5
# Available groups: ['presleep_2017-11-13_10-03-32']
# Processing file: E:\Donders\3\processed\OD\post_trial1_2017-11-16_11-23-46\post_trial1_2017-11-16_11-23-46_REM_dict.h5
# Available groups: ['post_trial1_2017-11-16_11-23-46']
# (85001, 6)
# shape power matrix: (125, 85001)
# shape of fpp_plots (141, 125, 19)
# (125, 141)
# fpp_list length: 136
# Processing file: E:\Donders\3\processed\OD\post_trial2_2017-11-16_12-14-17\post_trial2_2017-11-16_12-14-17_REM_dict.h5
# Available groups: ['post_trial2_2017-11-16_12-14-17']
# (232501, 6)
# shape power matrix: (125, 232501)
# shape of fpp_plots (3, 125, 19)
# (125, 3)
# fpp_list length: 137
# Processing file: E:\Donders\3\processed\OD\post_trial3_2017-11-16_13-04-51\post_trial3_2017-11-16_13-04-51_REM_dict.h5
# Available groups: ['post_trial3_2017-11-16_13-04-51']
# (182501, 6)
# shape power matrix: (125, 182501)
# shape of fpp_plots (122, 125, 19)
# (125, 122)
# fpp_list length: 138
# (505001, 6)
# shape power matrix: (125, 505001)
# shape of fpp_plots (198, 125, 19)
# (125, 198)
# fpp_list length: 139
# (342501, 6)
# shape power matrix: (125, 342501)
# shape of fpp_plots (136, 125, 19)
# (125, 136)
# fpp_list length: 140
# Processing file: E:\Donders\3\processed\OD\post_trial4_2017-11-16_13-55-23\post_trial4_2017-11-16_13-55-23_REM_dict.h5
# Available groups: ['post_trial4_2017-11-16_13-55-23']
# (275001, 6)
# shape power matrix: (125, 275001)
# shape of fpp_plots (38, 125, 19)
# (125, 38)
# fpp_list length: 141
# (560001, 6)
# shape power matrix: (125, 560001)
# shape of fpp_plots (123, 125, 19)
# (125, 123)
# fpp_list length: 142
# (40001, 6)
# shape power matrix: (125, 40001)
# shape of fpp_plots (9, 125, 19)
# (125, 9)
# fpp_list length: 143
# Processing file: E:\Donders\3\processed\OD\post_trial5_2017-11-16_14-46-12\post_trial5_2017-11-16_14-46-12_REM_dict.h5
# Available groups: ['post_trial5_2017-11-16_14-46-12']
# (367501, 6)
# shape power matrix: (125, 367501)
# shape of fpp_plots (30, 125, 19)
# (125, 30)
# fpp_list length: 144
# (47501, 6)
# shape power matrix: (125, 47501)
# shape of fpp_plots (5, 125, 19)
# (125, 5)
# fpp_list length: 145
# (115001, 6)
# shape power matrix: (125, 115001)
# shape of fpp_plots (18, 125, 19)
# (125, 18)
# fpp_list length: 146
# (37501, 6)
# shape power matrix: (125, 37501)
# shape of fpp_plots (1, 125, 19)
# (125, 1)
# fpp_list length: 147
# (257501, 6)
# shape power matrix: (125, 257501)
# shape of fpp_plots (30, 125, 19)
# (125, 30)
# fpp_list length: 148
# (147501, 6)
# shape power matrix: (125, 147501)
# shape of fpp_plots (12, 125, 19)
# (125, 12)
# fpp_list length: 149
# (192501, 6)
# shape power matrix: (125, 192501)
# shape of fpp_plots (6, 125, 19)
# (125, 6)
# fpp_list length: 150
# (155001, 6)
# shape power matrix: (125, 155001)
# shape of fpp_plots (9, 125, 19)
# (125, 9)
# fpp_list length: 151
# (515001, 6)
# shape power matrix: (125, 515001)
# shape of fpp_plots (47, 125, 19)
# (125, 47)
# fpp_list length: 152
# (137501, 6)
# shape power matrix: (125, 137501)
# shape of fpp_plots (3, 125, 19)
# (125, 3)
# fpp_list length: 153
# (265001, 6)
# shape power matrix: (125, 265001)
# shape of fpp_plots (4, 125, 19)
# (125, 4)
# fpp_list length: 154
# (227501, 6)
# shape power matrix: (125, 227501)
# shape of fpp_plots (21, 125, 19)
# (125, 21)
# fpp_list length: 155
# (200001, 6)
# shape power matrix: (125, 200001)
# shape of fpp_plots (7, 125, 19)
# (125, 7)
# fpp_list length: 156
# Processing file: E:\Donders\3\processed\OD\presleep_2017-11-16_10-32-38\presleep_2017-11-16_10-32-38_REM_dict.h5
# Available groups: ['presleep_2017-11-16_10-32-38']
# Processing file: E:\Donders\3\processed\Rat_OS_Ephys_Rat3_SD1_OR_08-09_11_2017\post_trial1_2017-11-08_12-53-19\post_trial1_2017-11-08_12-53-19_REM_dict.h5
# Available groups: ['post_trial1_2017-11-08_12-53-19']
# Processing file: E:\Donders\3\processed\Rat_OS_Ephys_Rat3_SD1_OR_08-09_11_2017\post_trial2_2017-11-08_13-46-10\post_trial2_2017-11-08_13-46-10_REM_dict.h5
# Available groups: ['post_trial2_2017-11-08_13-46-10']
# Processing file: E:\Donders\3\processed\Rat_OS_Ephys_Rat3_SD1_OR_08-09_11_2017\post_trial3_2017-11-08_14-36-57\post_trial3_2017-11-08_14-36-57_REM_dict.h5
# Available groups: ['post_trial3_2017-11-08_14-36-57']
# Processing file: E:\Donders\3\processed\Rat_OS_Ephys_Rat3_SD1_OR_08-09_11_2017\post_trial4_2017-11-08_15-27-43\post_trial4_2017-11-08_15-27-43_REM_dict.h5
# Available groups: ['post_trial4_2017-11-08_15-27-43']
# (182501, 6)
# shape power matrix: (125, 182501)
# shape of fpp_plots (195, 125, 19)
# (125, 195)
# fpp_list length: 157
# Processing file: E:\Donders\3\processed\Rat_OS_Ephys_Rat3_SD1_OR_08-09_11_2017\post_trial5_2017-11-08_16-18-24\post_trial5_2017-11-08_16-18-24_REM_dict.h5
# Available groups: ['post_trial5_2017-11-08_16-18-24']
# (37501, 6)
# shape power matrix: (125, 37501)
# shape of fpp_plots (50, 125, 19)
# (125, 50)
# fpp_list length: 158
# (25001, 6)
# shape power matrix: (125, 25001)
# shape of fpp_plots (47, 125, 19)
# (125, 47)
# fpp_list length: 159
# (277501, 6)
# shape power matrix: (125, 277501)
# shape of fpp_plots (388, 125, 19)
# (125, 388)
# fpp_list length: 160
# (245001, 6)
# shape power matrix: (125, 245001)
# shape of fpp_plots (537, 125, 19)
# (125, 537)
# fpp_list length: 161
# (117501, 6)
# shape power matrix: (125, 117501)
# shape of fpp_plots (116, 125, 19)
# (125, 116)
# fpp_list length: 162
# (45001, 6)
# shape power matrix: (125, 45001)
# shape of fpp_plots (62, 125, 19)
# (125, 62)
# fpp_list length: 163
# (20001, 6)
# shape power matrix: (125, 20001)
# shape of fpp_plots (26, 125, 19)
# (125, 26)
# fpp_list length: 164
# (255001, 6)
# shape power matrix: (125, 255001)
# shape of fpp_plots (268, 125, 19)
# (125, 268)
# fpp_list length: 165
# (15001, 6)
# shape power matrix: (125, 15001)
# shape of fpp_plots (22, 125, 19)
# (125, 22)
# fpp_list length: 166
# (45001, 6)
# shape power matrix: (125, 45001)
# shape of fpp_plots (69, 125, 19)
# (125, 69)
# fpp_list length: 167
# (565001, 6)
# shape power matrix: (125, 565001)
# shape of fpp_plots (810, 125, 19)
# (125, 810)
# fpp_list length: 168
# (40001, 6)
# shape power matrix: (125, 40001)
# shape of fpp_plots (51, 125, 19)
# (125, 51)
# fpp_list length: 169
# Processing file: E:\Donders\3\processed\Rat_OS_Ephys_Rat3_SD1_OR_08-09_11_2017\presleep_2017-11-08_12-01-47\presleep_2017-11-08_12-01-47_REM_dict.h5
# Available groups: ['presleep_2017-11-08_12-01-47']
# Processing file: E:\Donders\3\processed\Rat_OS_Ephys_Rat3_SD3_HC_15_11_2017\post_trial1_2017-11-15_10-42-55\post_trial1_2017-11-15_10-42-55_REM_dict.h5
# Available groups: ['post_trial1_2017-11-15_10-42-55']
# Processing file: E:\Donders\3\processed\Rat_OS_Ephys_Rat3_SD3_HC_15_11_2017\post_trial2_2017-11-15_11-33-31\post_trial2_2017-11-15_11-33-31_REM_dict.h5
# Available groups: ['post_trial2_2017-11-15_11-33-31']
# Processing file: E:\Donders\3\processed\Rat_OS_Ephys_Rat3_SD3_HC_15_11_2017\post_trial3_2017-11-15_12-23-47\post_trial3_2017-11-15_12-23-47_REM_dict.h5
# Available groups: ['post_trial3_2017-11-15_12-23-47']
# (540001, 6)
# shape power matrix: (125, 540001)
# shape of fpp_plots (631, 125, 19)
# (125, 631)
# fpp_list length: 170
# Processing file: E:\Donders\3\processed\Rat_OS_Ephys_Rat3_SD3_HC_15_11_2017\post_trial4_2017-11-15_13-14-18\post_trial4_2017-11-15_13-14-18_REM_dict.h5
# Available groups: ['post_trial4_2017-11-15_13-14-18']
# (17501, 6)
# shape power matrix: (125, 17501)
# shape of fpp_plots (30, 125, 19)
# (125, 30)
# fpp_list length: 171
# (12501, 6)
# shape power matrix: (125, 12501)
# shape of fpp_plots (24, 125, 19)
# (125, 24)
# fpp_list length: 172
# Processing file: E:\Donders\3\processed\Rat_OS_Ephys_Rat3_SD3_HC_15_11_2017\post_trial5_2017-11-15_14-04-39\post_trial5_2017-11-15_14-04-39_REM_dict.h5
# Available groups: ['post_trial5_2017-11-15_14-04-39']
# (132501, 6)
# shape power matrix: (125, 132501)
# shape of fpp_plots (134, 125, 19)
# (125, 134)
# fpp_list length: 173
# (142501, 6)
# shape power matrix: (125, 142501)
# shape of fpp_plots (315, 125, 19)
# (125, 315)
# fpp_list length: 174
# (210001, 6)
# shape power matrix: (125, 210001)
# shape of fpp_plots (403, 125, 19)
# (125, 403)
# fpp_list length: 175
# (170001, 6)
# shape power matrix: (125, 170001)
# shape of fpp_plots (336, 125, 19)
# (125, 336)
# fpp_list length: 176
# (385001, 6)
# shape power matrix: (125, 385001)
# shape of fpp_plots (679, 125, 19)
# (125, 679)
# fpp_list length: 177
# (40001, 6)
# shape power matrix: (125, 40001)
# shape of fpp_plots (52, 125, 19)
# (125, 52)
# fpp_list length: 178
# (395001, 6)
# shape power matrix: (125, 395001)
# shape of fpp_plots (746, 125, 19)
# (125, 746)
# fpp_list length: 179
# (290001, 6)
# shape power matrix: (125, 290001)
# shape of fpp_plots (478, 125, 19)
# (125, 478)
# fpp_list length: 180
# (130001, 6)
# shape power matrix: (125, 130001)
# shape of fpp_plots (222, 125, 19)
# (125, 222)
# fpp_list length: 181
# (250001, 6)
# shape power matrix: (125, 250001)
# shape of fpp_plots (387, 125, 19)
# (125, 387)
# fpp_list length: 182
# (37501, 6)
# shape power matrix: (125, 37501)
# shape of fpp_plots (49, 125, 19)
# (125, 49)
# fpp_list length: 183
# Processing file: E:\Donders\3\processed\Rat_OS_Ephys_Rat3_SD3_HC_15_11_2017\presleep_2017-11-15_09-52-08\presleep_2017-11-15_09-52-08_REM_dict.h5
# Available groups: ['presleep_2017-11-15_09-52-08']
# Processing file: E:\Donders\3\processed\Rat_OS_Ephys_Rat3_SD5_OR_N_21-22_11_2017\post_trial1_2017-11-21_10-53-58\post_trial1_2017-11-21_10-53-58_REM_dict.h5
# Available groups: ['post_trial1_2017-11-21_10-53-58']
# Processing file: E:\Donders\3\processed\Rat_OS_Ephys_Rat3_SD5_OR_N_21-22_11_2017\post_trial2_2017-11-21_11-44-35\post_trial2_2017-11-21_11-44-35_REM_dict.h5
# Available groups: ['post_trial2_2017-11-21_11-44-35']
# Processing file: E:\Donders\3\processed\Rat_OS_Ephys_Rat3_SD5_OR_N_21-22_11_2017\post_trial3_2017-11-21_12-35-06\post_trial3_2017-11-21_12-35-06_REM_dict.h5
# Available groups: ['post_trial3_2017-11-21_12-35-06']
# Processing file: E:\Donders\3\processed\Rat_OS_Ephys_Rat3_SD5_OR_N_21-22_11_2017\post_trial4_2017-11-21_13-25-29\post_trial4_2017-11-21_13-25-29_REM_dict.h5
# Available groups: ['post_trial4_2017-11-21_13-25-29']
# (217501, 6)
# shape power matrix: (125, 217501)
# shape of fpp_plots (609, 125, 19)
# (125, 609)
# fpp_list length: 184
# (152501, 6)
# shape power matrix: (125, 152501)
# shape of fpp_plots (397, 125, 19)
# (125, 397)
# fpp_list length: 185
# Processing file: E:\Donders\3\processed\Rat_OS_Ephys_Rat3_SD5_OR_N_21-22_11_2017\post_trial5_2017-11-21_14-49-47\post_trial5_2017-11-21_14-49-47_REM_dict.h5
# Available groups: ['post_trial5_2017-11-21_14-49-47']
# (432501, 6)
# shape power matrix: (125, 432501)
# shape of fpp_plots (742, 125, 19)
# (125, 742)
# fpp_list length: 186
# (190001, 6)
# shape power matrix: (125, 190001)
# shape of fpp_plots (479, 125, 19)
# (125, 479)
# fpp_list length: 187
# (285001, 6)
# shape power matrix: (125, 285001)
# shape of fpp_plots (678, 125, 19)
# (125, 678)
# fpp_list length: 188
# (377501, 6)
# shape power matrix: (125, 377501)
# shape of fpp_plots (883, 125, 19)
# (125, 883)
# fpp_list length: 189
# (202501, 6)
# shape power matrix: (125, 202501)
# shape of fpp_plots (496, 125, 19)
# (125, 496)
# fpp_list length: 190
# (162501, 6)
# shape power matrix: (125, 162501)
# shape of fpp_plots (289, 125, 19)
# (125, 289)
# fpp_list length: 191
# (80001, 6)
# shape power matrix: (125, 80001)
# shape of fpp_plots (179, 125, 19)
# (125, 179)
# fpp_list length: 192
# (567501, 6)
# shape power matrix: (125, 567501)
# shape of fpp_plots (860, 125, 19)
# (125, 860)
# fpp_list length: 193
# Processing file: E:\Donders\3\processed\Rat_OS_Ephys_Rat3_SD5_OR_N_21-22_11_2017\presleep_2017-11-21_10-03-24\presleep_2017-11-21_10-03-24_REM_dict.h5
# Available groups: ['presleep_2017-11-21_10-03-24']
# Processing file: E:\Donders\3\processed\Rat_OS_Ephys_Rat3_SD6_HC_23_11_2017\post_trial1_2017-11-23_10-53-13\post_trial1_2017-11-23_10-53-13_REM_dict.h5
# Available groups: ['post_trial1_2017-11-23_10-53-13']
# (142501, 6)
# shape power matrix: (125, 142501)
# shape of fpp_plots (332, 125, 19)
# (125, 332)
# fpp_list length: 194
# Processing file: E:\Donders\3\processed\Rat_OS_Ephys_Rat3_SD6_HC_23_11_2017\post_trial2_2017-11-23_11-43-29\post_trial2_2017-11-23_11-43-29_REM_dict.h5
# Available groups: ['post_trial2_2017-11-23_11-43-29']
# (100001, 6)
# shape power matrix: (125, 100001)
# shape of fpp_plots (241, 125, 19)
# (125, 241)
# fpp_list length: 195
# (117501, 6)
# shape power matrix: (125, 117501)
# shape of fpp_plots (298, 125, 19)
# (125, 298)
# fpp_list length: 196
# (40001, 6)
# shape power matrix: (125, 40001)
# shape of fpp_plots (118, 125, 19)
# (125, 118)
# fpp_list length: 197
# (85001, 6)
# shape power matrix: (125, 85001)
# shape of fpp_plots (153, 125, 19)
# (125, 153)
# fpp_list length: 198
# Processing file: E:\Donders\3\processed\Rat_OS_Ephys_Rat3_SD6_HC_23_11_2017\post_trial3_2017-11-23_12-33-48\post_trial3_2017-11-23_12-33-48_REM_dict.h5
# Available groups: ['post_trial3_2017-11-23_12-33-48']
# (365001, 6)
# shape power matrix: (125, 365001)
# shape of fpp_plots (922, 125, 19)
# (125, 922)
# fpp_list length: 199
# Processing file: E:\Donders\3\processed\Rat_OS_Ephys_Rat3_SD6_HC_23_11_2017\post_trial4_2017-11-23_13-24-05\post_trial4_2017-11-23_13-24-05_REM_dict.h5
# Available groups: ['post_trial4_2017-11-23_13-24-05']
# (365001, 6)
# shape power matrix: (125, 365001)
# shape of fpp_plots (234, 125, 19)
# (125, 234)
# fpp_list length: 200
# (60001, 6)
# shape power matrix: (125, 60001)
# shape of fpp_plots (57, 125, 19)
# (125, 57)
# fpp_list length: 201
# (102501, 6)
# shape power matrix: (125, 102501)
# shape of fpp_plots (38, 125, 19)
# (125, 38)
# fpp_list length: 202
# (95001, 6)
# shape power matrix: (125, 95001)
# shape of fpp_plots (37, 125, 19)
# (125, 37)
# fpp_list length: 203
# Processing file: E:\Donders\3\processed\Rat_OS_Ephys_Rat3_SD6_HC_23_11_2017\post_trial5_2017-11-23_14-14-20\post_trial5_2017-11-23_14-14-20_REM_dict.h5
# Available groups: ['post_trial5_2017-11-23_14-14-20']
# (405001, 6)
# shape power matrix: (125, 405001)
# shape of fpp_plots (602, 125, 19)
# (125, 602)
# fpp_list length: 204
# (147501, 6)
# shape power matrix: (125, 147501)
# shape of fpp_plots (197, 125, 19)
# (125, 197)
# fpp_list length: 205
# (267501, 6)
# shape power matrix: (125, 267501)
# shape of fpp_plots (452, 125, 19)
# (125, 452)
# fpp_list length: 206
# (90001, 6)
# shape power matrix: (125, 90001)
# shape of fpp_plots (156, 125, 19)
# (125, 156)
# fpp_list length: 207
# (157501, 6)
# shape power matrix: (125, 157501)
# shape of fpp_plots (264, 125, 19)
# (125, 264)
# fpp_list length: 208
# (80001, 6)
# shape power matrix: (125, 80001)
# shape of fpp_plots (79, 125, 19)
# (125, 79)
# fpp_list length: 209
# Processing file: E:\Donders\3\processed\Rat_OS_Ephys_Rat3_SD6_HC_23_11_2017\presleep_2017-11-23_10-02-18\presleep_2017-11-23_10-02-18_REM_dict.h5
# Available groups: ['presleep_2017-11-23_10-02-18']
# Processing file: E:\Donders\4\processed\CN\post_trial1_2017-12-11_11-10-55\post_trial1_2017-12-11_11-10-55_REM_dict.h5
# Available groups: ['post_trial1_2017-12-11_11-10-55']
# Processing file: E:\Donders\4\processed\CN\post_trial2_2017-12-11_12-01-50\post_trial2_2017-12-11_12-01-50_REM_dict.h5
# Available groups: ['post_trial2_2017-12-11_12-01-50']
# (272500, 6)
# shape power matrix: (125, 272500)
# shape of fpp_plots (418, 125, 19)
# (125, 418)
# fpp_list length: 210
# (52500, 6)
# shape power matrix: (125, 52500)
# shape of fpp_plots (95, 125, 19)
# (125, 95)
# fpp_list length: 211
# (485000, 6)
# shape power matrix: (125, 485000)
# shape of fpp_plots (827, 125, 19)
# (125, 827)
# fpp_list length: 212
# Processing file: E:\Donders\4\processed\CN\post_trial3_2017-12-11_12-52-58\post_trial3_2017-12-11_12-52-58_REM_dict.h5
# Available groups: ['post_trial3_2017-12-11_12-52-58']
# (42500, 6)
# shape power matrix: (125, 42500)
# shape of fpp_plots (73, 125, 19)
# (125, 73)
# fpp_list length: 213
# (347500, 6)
# shape power matrix: (125, 347500)
# shape of fpp_plots (940, 125, 19)
# (125, 940)
# fpp_list length: 214
# (292500, 6)
# shape power matrix: (125, 292500)
# shape of fpp_plots (538, 125, 19)
# (125, 538)
# fpp_list length: 215
# (280000, 6)
# shape power matrix: (125, 280000)
# shape of fpp_plots (722, 125, 19)
# (125, 722)
# fpp_list length: 216
# (240000, 6)
# shape power matrix: (125, 240000)
# shape of fpp_plots (577, 125, 19)
# (125, 577)
# fpp_list length: 217
# Processing file: E:\Donders\4\processed\CN\post_trial4_2017-12-11_13-43-39\post_trial4_2017-12-11_13-43-39_REM_dict.h5
# Available groups: ['post_trial4_2017-12-11_13-43-39']
# (100000, 6)
# shape power matrix: (125, 100000)
# shape of fpp_plots (183, 125, 19)
# (125, 183)
# fpp_list length: 218
# (337500, 6)
# shape power matrix: (125, 337500)
# shape of fpp_plots (480, 125, 19)
# (125, 480)
# fpp_list length: 219
# (160000, 6)
# shape power matrix: (125, 160000)
# shape of fpp_plots (230, 125, 19)
# (125, 230)
# fpp_list length: 220
# (290000, 6)
# shape power matrix: (125, 290000)
# shape of fpp_plots (488, 125, 19)
# (125, 488)
# fpp_list length: 221
# Processing file: E:\Donders\4\processed\CN\post_trial5_2017-12-11_14-34-11\post_trial5_2017-12-11_14-34-11_REM_dict.h5
# Available groups: ['post_trial5_2017-12-11_14-34-11']
# (352500, 6)
# shape power matrix: (125, 352500)
# shape of fpp_plots (492, 125, 19)
# (125, 492)
# fpp_list length: 222
# (137500, 6)
# shape power matrix: (125, 137500)
# shape of fpp_plots (193, 125, 19)
# (125, 193)
# fpp_list length: 223
# (135000, 6)
# shape power matrix: (125, 135000)
# shape of fpp_plots (223, 125, 19)
# (125, 223)
# fpp_list length: 224
# (325000, 6)
# shape power matrix: (125, 325000)
# shape of fpp_plots (570, 125, 19)
# (125, 570)
# fpp_list length: 225
# (420000, 6)
# shape power matrix: (125, 420000)
# shape of fpp_plots (711, 125, 19)
# (125, 711)
# fpp_list length: 226
# (82500, 6)
# shape power matrix: (125, 82500)
# shape of fpp_plots (107, 125, 19)
# (125, 107)
# fpp_list length: 227
# (120000, 6)
# shape power matrix: (125, 120000)
# shape of fpp_plots (160, 125, 19)
# (125, 160)
# fpp_list length: 228
# (325000, 6)
# shape power matrix: (125, 325000)
# shape of fpp_plots (409, 125, 19)
# (125, 409)
# fpp_list length: 229
# (132500, 6)
# shape power matrix: (125, 132500)
# shape of fpp_plots (189, 125, 19)
# (125, 189)
# fpp_list length: 230
# (105000, 6)
# shape power matrix: (125, 105000)
# shape of fpp_plots (183, 125, 19)
# (125, 183)
# fpp_list length: 231
# Processing file: E:\Donders\4\processed\CN\presleep_2017-12-11_10-16-03\presleep_2017-12-11_10-16-03_REM_dict.h5
# Available groups: ['presleep_2017-12-11_10-16-03']
# Processing file: E:\Donders\4\processed\OD\post_trial1_2017-12-21_12-38-37\post_trial1_2017-12-21_12-38-37_REM_dict.h5
# Available groups: ['post_trial1_2017-12-21_12-38-37']
# (267500, 6)
# shape power matrix: (125, 267500)
# shape of fpp_plots (749, 125, 19)
# (125, 749)
# fpp_list length: 232
# Processing file: E:\Donders\4\processed\OD\post_trial2_2017-12-21_13-29-12\post_trial2_2017-12-21_13-29-12_REM_dict.h5
# Available groups: ['post_trial2_2017-12-21_13-29-12']
# (312500, 6)
# shape power matrix: (125, 312500)
# shape of fpp_plots (0,)
# Error: Dimensions of fpp_plots are too small.
# (87500, 6)
# shape power matrix: (125, 87500)
# shape of fpp_plots (66, 125, 19)
# (125, 66)
# fpp_list length: 233
# (145000, 6)
# shape power matrix: (125, 145000)
# shape of fpp_plots (126, 125, 19)
# (125, 126)
# fpp_list length: 234
# (57500, 6)
# shape power matrix: (125, 57500)
# shape of fpp_plots (52, 125, 19)
# (125, 52)
# fpp_list length: 235
# Processing file: E:\Donders\4\processed\OD\post_trial3_2017-12-21_14-19-43\post_trial3_2017-12-21_14-19-43_REM_dict.h5
# Available groups: ['post_trial3_2017-12-21_14-19-43']
# (50000, 6)
# shape power matrix: (125, 50000)
# shape of fpp_plots (81, 125, 19)
# (125, 81)
# fpp_list length: 236
# (247500, 6)
# shape power matrix: (125, 247500)
# shape of fpp_plots (461, 125, 19)
# (125, 461)
# fpp_list length: 237
# (382500, 6)
# shape power matrix: (125, 382500)
# shape of fpp_plots (605, 125, 19)
# (125, 605)
# fpp_list length: 238
# Processing file: E:\Donders\4\processed\OD\post_trial4_2017-12-21_15-11-18\post_trial4_2017-12-21_15-11-18_REM_dict.h5
# Available groups: ['post_trial4_2017-12-21_15-11-18']
# (402500, 6)
# shape power matrix: (125, 402500)
# shape of fpp_plots (692, 125, 19)
# (125, 692)
# fpp_list length: 239
# (390000, 6)
# shape power matrix: (125, 390000)
# shape of fpp_plots (968, 125, 19)
# (125, 968)
# fpp_list length: 240
# (410000, 6)
# shape power matrix: (125, 410000)
# shape of fpp_plots (831, 125, 19)
# (125, 831)
# fpp_list length: 241
# Processing file: E:\Donders\4\processed\OD\post_trial5_2017-12-21_16-02-00\post_trial5_2017-12-21_16-02-00_REM_dict.h5
# Available groups: ['post_trial5_2017-12-21_16-02-00']
# (300000, 6)
# shape power matrix: (125, 300000)
# shape of fpp_plots (812, 125, 19)
# (125, 812)
# fpp_list length: 242
# (40000, 6)
# shape power matrix: (125, 40000)
# shape of fpp_plots (79, 125, 19)
# (125, 79)
# fpp_list length: 243
# (135000, 6)
# shape power matrix: (125, 135000)
# shape of fpp_plots (351, 125, 19)
# (125, 351)
# fpp_list length: 244
# (82500, 6)
# shape power matrix: (125, 82500)
# shape of fpp_plots (187, 125, 19)
# (125, 187)
# fpp_list length: 245
# (245000, 6)
# shape power matrix: (125, 245000)
# shape of fpp_plots (525, 125, 19)
# (125, 525)
# fpp_list length: 246
# (340000, 6)
# shape power matrix: (125, 340000)
# shape of fpp_plots (950, 125, 19)
# (125, 950)
# fpp_list length: 247
# (122500, 6)
# shape power matrix: (125, 122500)
# shape of fpp_plots (342, 125, 19)
# (125, 342)
# fpp_list length: 248
# (312500, 6)
# shape power matrix: (125, 312500)
# shape of fpp_plots (850, 125, 19)
# (125, 850)
# fpp_list length: 249
# (190000, 6)
# shape power matrix: (125, 190000)
# shape of fpp_plots (496, 125, 19)
# (125, 496)
# fpp_list length: 250
# (55000, 6)
# shape power matrix: (125, 55000)
# shape of fpp_plots (138, 125, 19)
# (125, 138)
# fpp_list length: 251
# (150000, 6)
# shape power matrix: (125, 150000)
# shape of fpp_plots (347, 125, 19)
# (125, 347)
# fpp_list length: 252
# (310000, 6)
# shape power matrix: (125, 310000)
# shape of fpp_plots (887, 125, 19)
# (125, 887)
# fpp_list length: 253
# (242500, 6)
# shape power matrix: (125, 242500)
# shape of fpp_plots (544, 125, 19)
# (125, 544)
# fpp_list length: 254
# (40000, 6)
# shape power matrix: (125, 40000)
# shape of fpp_plots (78, 125, 19)
# (125, 78)
# fpp_list length: 255
# Processing file: E:\Donders\4\processed\OD\presleep_2017-12-21_11-48-07\presleep_2017-12-21_11-48-07_REM_dict.h5
# Available groups: ['presleep_2017-12-21_11-48-07']
# Processing file: E:\Donders\4\processed\Rat_OS_Ephys_Rat4_SD2_HC_13_12_2017\post_trial1_2017-12-13_09-11-31\post_trial1_2017-12-13_09-11-31_REM_dict.h5
# Available groups: ['post_trial1_2017-12-13_09-11-31']
# Processing file: E:\Donders\4\processed\Rat_OS_Ephys_Rat4_SD2_HC_13_12_2017\post_trial2_2017-12-13_10-01-43\post_trial2_2017-12-13_10-01-43_REM_dict.h5
# Available groups: ['post_trial2_2017-12-13_10-01-43']
# Processing file: E:\Donders\4\processed\Rat_OS_Ephys_Rat4_SD2_HC_13_12_2017\post_trial3_2017-12-13_10-53-01\post_trial3_2017-12-13_10-53-01_REM_dict.h5
# Available groups: ['post_trial3_2017-12-13_10-53-01']
# Processing file: E:\Donders\4\processed\Rat_OS_Ephys_Rat4_SD2_HC_13_12_2017\post_trial4_2017-12-13_11-43-15\post_trial4_2017-12-13_11-43-15_REM_dict.h5
# Available groups: ['post_trial4_2017-12-13_11-43-15']
# (147500, 6)
# shape power matrix: (125, 147500)
# shape of fpp_plots (400, 125, 19)
# (125, 400)
# fpp_list length: 256
# (25000, 6)
# shape power matrix: (125, 25000)
# shape of fpp_plots (63, 125, 19)
# (125, 63)
# fpp_list length: 257
# (305000, 6)
# shape power matrix: (125, 305000)
# shape of fpp_plots (803, 125, 19)
# (125, 803)
# fpp_list length: 258
# Processing file: E:\Donders\4\processed\Rat_OS_Ephys_Rat4_SD2_HC_13_12_2017\post_trial5_2017-12-13_12-33-28\post_trial5_2017-12-13_12-33-28_REM_dict.h5
# Available groups: ['post_trial5_2017-12-13_12-33-28']
# (22500, 6)
# shape power matrix: (125, 22500)
# shape of fpp_plots (1, 125, 19)
# (125, 1)
# fpp_list length: 259
# (75000, 6)
# shape power matrix: (125, 75000)
# shape of fpp_plots (4, 125, 19)
# (125, 4)
# fpp_list length: 260
# (325000, 6)
# shape power matrix: (125, 325000)
# shape of fpp_plots (53, 125, 19)
# (125, 53)
# fpp_list length: 261
# (325000, 6)
# shape power matrix: (125, 325000)
# shape of fpp_plots (111, 125, 19)
# (125, 111)
# fpp_list length: 262
# (37500, 6)
# shape power matrix: (125, 37500)
# shape of fpp_plots (10, 125, 19)
# (125, 10)
# fpp_list length: 263
# (107500, 6)
# shape power matrix: (125, 107500)
# shape of fpp_plots (16, 125, 19)
# (125, 16)
# fpp_list length: 264
# (435000, 6)
# shape power matrix: (125, 435000)
# shape of fpp_plots (87, 125, 19)
# (125, 87)
# fpp_list length: 265
# (147500, 6)
# shape power matrix: (125, 147500)
# shape of fpp_plots (37, 125, 19)
# (125, 37)
# fpp_list length: 266
# (387500, 6)
# shape power matrix: (125, 387500)
# shape of fpp_plots (58, 125, 19)
# (125, 58)
# fpp_list length: 267
# (230000, 6)
# shape power matrix: (125, 230000)
# shape of fpp_plots (73, 125, 19)
# (125, 73)
# fpp_list length: 268
# (162500, 6)
# shape power matrix: (125, 162500)
# shape of fpp_plots (37, 125, 19)
# (125, 37)
# fpp_list length: 269
# (92500, 6)
# shape power matrix: (125, 92500)
# shape of fpp_plots (14, 125, 19)
# (125, 14)
# fpp_list length: 270
# (37500, 6)
# shape power matrix: (125, 37500)
# shape of fpp_plots (1, 125, 19)
# (125, 1)
# fpp_list length: 271
# (237500, 6)
# shape power matrix: (125, 237500)
# shape of fpp_plots (0,)
# Error: Dimensions of fpp_plots are too small.
# (455000, 6)
# shape power matrix: (125, 455000)
# shape of fpp_plots (11, 125, 19)
# (125, 11)
# fpp_list length: 272
# (565000, 6)
# shape power matrix: (125, 565000)
# shape of fpp_plots (20, 125, 19)
# (125, 20)
# fpp_list length: 273
# Processing file: E:\Donders\4\processed\Rat_OS_Ephys_Rat4_SD2_HC_13_12_2017\presleep_2017-12-13_08-19-49\presleep_2017-12-13_08-19-49_REM_dict.h5
# Available groups: ['presleep_2017-12-13_08-19-49']
# Processing file: E:\Donders\4\processed\Rat_OS_Ephys_Rat4_SD3_OR_11-12_12_2017\post_trial1_2017-12-14_10-21-20\post_trial1_2017-12-14_10-21-20_REM_dict.h5
# Available groups: ['post_trial1_2017-12-14_10-21-20']
# Processing file: E:\Donders\4\processed\Rat_OS_Ephys_Rat4_SD3_OR_11-12_12_2017\post_trial2_2017-12-14_11-11-59\post_trial2_2017-12-14_11-11-59_REM_dict.h5
# Available groups: ['post_trial2_2017-12-14_11-11-59']
# Processing file: E:\Donders\4\processed\Rat_OS_Ephys_Rat4_SD3_OR_11-12_12_2017\post_trial3_2017-12-14_12-03-16\post_trial3_2017-12-14_12-03-16_REM_dict.h5
# Available groups: ['post_trial3_2017-12-14_12-03-16']
# (270000, 6)
# shape power matrix: (125, 270000)
# shape of fpp_plots (636, 125, 19)
# (125, 636)
# fpp_list length: 274
# (50000, 6)
# shape power matrix: (125, 50000)
# shape of fpp_plots (91, 125, 19)
# (125, 91)
# fpp_list length: 275
# Processing file: E:\Donders\4\processed\Rat_OS_Ephys_Rat4_SD3_OR_11-12_12_2017\post_trial4_2017-12-14_12-53-59\post_trial4_2017-12-14_12-53-59_REM_dict.h5
# Available groups: ['post_trial4_2017-12-14_12-53-59']
# (72500, 6)
# shape power matrix: (125, 72500)
# shape of fpp_plots (116, 125, 19)
# (125, 116)
# fpp_list length: 276
# (180000, 6)
# shape power matrix: (125, 180000)
# shape of fpp_plots (372, 125, 19)
# (125, 372)
# fpp_list length: 277
# (235000, 6)
# shape power matrix: (125, 235000)
# shape of fpp_plots (376, 125, 19)
# (125, 376)
# fpp_list length: 278
# (642500, 6)
# shape power matrix: (125, 642500)
# shape of fpp_plots (936, 125, 19)
# (125, 936)
# fpp_list length: 279
# Processing file: E:\Donders\4\processed\Rat_OS_Ephys_Rat4_SD3_OR_11-12_12_2017\post_trial5_2017-12-14_13-44-46\post_trial5_2017-12-14_13-44-46_REM_dict.h5
# Available groups: ['post_trial5_2017-12-14_13-44-46']
# (55000, 6)
# shape power matrix: (125, 55000)
# shape of fpp_plots (95, 125, 19)
# (125, 95)
# fpp_list length: 280
# (17500, 6)
# shape power matrix: (125, 17500)
# shape of fpp_plots (33, 125, 19)
# (125, 33)
# fpp_list length: 281
# (372500, 6)
# shape power matrix: (125, 372500)
# ...
# (125, 734)
# fpp_list length: 648
# (257500, 6)
# shape power matrix: (125, 257500)
# shape of fpp_plots (730, 125, 19)
# (125, 730)
# fpp_list length: 649
# (305000, 6)
# shape power matrix: (125, 305000)
# shape of fpp_plots (707, 125, 19)
# (125, 707)
# fpp_list length: 650
# (210000, 6)
# shape power matrix: (125, 210000)
# shape of fpp_plots (511, 125, 19)
# (125, 511)
# fpp_list length: 651
# Processing file: E:\Donders\13\processed\Rat_OS_Ephys_Rat13_344994_SD11_OR_N_06-07_06_2019\2019-06-06_10-53-09_presleep\2019-06-06_10-53-09_presleep_REM_dict.h5
# Available groups: ['2019-06-06_10-53-09_presleep']
# Processing file: E:\Donders\13\processed\Rat_OS_Ephys_Rat13_344994_SD11_OR_N_06-07_06_2019\2019-06-06_11-44-01_post_trial1\2019-06-06_11-44-01_post_trial1_REM_dict.h5
# Available groups: ['2019-06-06_11-44-01_post_trial1']
# (365000, 6)
# shape power matrix: (125, 365000)
# shape of fpp_plots (623, 125, 19)
# (125, 623)
# fpp_list length: 652
# Processing file: E:\Donders\13\processed\Rat_OS_Ephys_Rat13_344994_SD11_OR_N_06-07_06_2019\2019-06-06_12-34-54_post_trial2\2019-06-06_12-34-54_post_trial2_REM_dict.h5
# Available groups: ['2019-06-06_12-34-54_post_trial2']
# (285000, 6)
# shape power matrix: (125, 285000)
# shape of fpp_plots (644, 125, 19)
# (125, 644)
# fpp_list length: 653
# (107500, 6)
# shape power matrix: (125, 107500)
# shape of fpp_plots (284, 125, 19)
# (125, 284)
# fpp_list length: 654
# (77500, 6)
# shape power matrix: (125, 77500)
# shape of fpp_plots (119, 125, 19)
# (125, 119)
# fpp_list length: 655
# Processing file: E:\Donders\13\processed\Rat_OS_Ephys_Rat13_344994_SD11_OR_N_06-07_06_2019\2019-06-06_13-26-20_post_trial3\2019-06-06_13-26-20_post_trial3_REM_dict.h5
# Available groups: ['2019-06-06_13-26-20_post_trial3']
# (307500, 6)
# shape power matrix: (125, 307500)
# shape of fpp_plots (886, 125, 19)
# (125, 886)
# fpp_list length: 656
# (10000, 6)
# shape power matrix: (125, 10000)
# shape of fpp_plots (15, 125, 19)
# (125, 15)
# fpp_list length: 657
# (565000, 6)
# shape power matrix: (125, 565000)
# shape of fpp_plots (1521, 125, 19)
# (125, 1521)
# fpp_list length: 658
# Processing file: E:\Donders\13\processed\Rat_OS_Ephys_Rat13_344994_SD11_OR_N_06-07_06_2019\2019-06-06_14-17-32_post_trial4\2019-06-06_14-17-32_post_trial4_REM_dict.h5
# Available groups: ['2019-06-06_14-17-32_post_trial4']
# (55000, 6)
# shape power matrix: (125, 55000)
# shape of fpp_plots (148, 125, 19)
# (125, 148)
# fpp_list length: 659
# (290000, 6)
# shape power matrix: (125, 290000)
# shape of fpp_plots (811, 125, 19)
# (125, 811)
# fpp_list length: 660
# (295000, 6)
# shape power matrix: (125, 295000)
# shape of fpp_plots (864, 125, 19)
# (125, 864)
# fpp_list length: 661
# Processing file: E:\Donders\13\processed\Rat_OS_Ephys_Rat13_344994_SD11_OR_N_06-07_06_2019\2019-06-06_15-39-11_post_trial5\2019-06-06_15-39-11_post_trial5_REM_dict.h5
# Available groups: ['2019-06-06_15-39-11_post_trial5']
# (390000, 6)
# shape power matrix: (125, 390000)
# shape of fpp_plots (1085, 125, 19)
# (125, 1085)
# fpp_list length: 662
# (205000, 6)
# shape power matrix: (125, 205000)
# shape of fpp_plots (587, 125, 19)
# (125, 587)
# fpp_list length: 663
# (190000, 6)
# shape power matrix: (125, 190000)
# shape of fpp_plots (558, 125, 19)
# (125, 558)
# fpp_list length: 664
# (345000, 6)
# shape power matrix: (125, 345000)
# shape of fpp_plots (984, 125, 19)
# (125, 984)
# fpp_list length: 665
# (410000, 6)
# shape power matrix: (125, 410000)
# shape of fpp_plots (1173, 125, 19)
# (125, 1173)
# fpp_list length: 666
# (60000, 6)
# shape power matrix: (125, 60000)
# shape of fpp_plots (162, 125, 19)
# (125, 162)
# fpp_list length: 667
# (435000, 6)
# shape power matrix: (125, 435000)
# shape of fpp_plots (1271, 125, 19)
# (125, 1271)
# fpp_list length: 668
# (102500, 6)
# shape power matrix: (125, 102500)
# shape of fpp_plots (304, 125, 19)
# (125, 304)
# fpp_list length: 669
# (415000, 6)
# shape power matrix: (125, 415000)
# shape of fpp_plots (1172, 125, 19)
# (125, 1172)
# fpp_list length: 670
# (52500, 6)
# shape power matrix: (125, 52500)
# shape of fpp_plots (143, 125, 19)
# (125, 143)
# fpp_list length: 671
# (102500, 6)
# shape power matrix: (125, 102500)
# shape of fpp_plots (289, 125, 19)
# (125, 289)
# fpp_list length: 672
# Processing file: E:\Donders\13\processed\Rat_OS_Ephys_Rat13_344994_SD12_OR_SD_10-11_06_2019\2019-06-10_13-10-58_presleep\2019-06-10_13-10-58_presleep_REM_dict.h5
# Available groups: ['2019-06-10_13-10-58_presleep']
# Processing file: E:\Donders\13\processed\Rat_OS_Ephys_Rat13_344994_SD12_OR_SD_10-11_06_2019\2019-06-10_14-01-35_post_trial1\2019-06-10_14-01-35_post_trial1_REM_dict.h5
# Available groups: ['2019-06-10_14-01-35_post_trial1']
# Processing file: E:\Donders\13\processed\Rat_OS_Ephys_Rat13_344994_SD12_OR_SD_10-11_06_2019\2019-06-10_14-52-28_post_trial2\2019-06-10_14-52-28_post_trial2_REM_dict.h5
# Available groups: ['2019-06-10_14-52-28_post_trial2']
# Processing file: E:\Donders\13\processed\Rat_OS_Ephys_Rat13_344994_SD12_OR_SD_10-11_06_2019\2019-06-10_15-43-16_post_trial3\2019-06-10_15-43-16_post_trial3_REM_dict.h5
# Available groups: ['2019-06-10_15-43-16_post_trial3']
# Processing file: E:\Donders\13\processed\Rat_OS_Ephys_Rat13_344994_SD12_OR_SD_10-11_06_2019\2019-06-10_16-34-14_post_trial4\2019-06-10_16-34-14_post_trial4_REM_dict.h5
# Available groups: ['2019-06-10_16-34-14_post_trial4']
# Processing file: E:\Donders\13\processed\Rat_OS_Ephys_Rat13_344994_SD12_OR_SD_10-11_06_2019\2019-06-10_17-24-55_post_trial5\2019-06-10_17-24-55_post_trial5_REM_dict.h5
# Available groups: ['2019-06-10_17-24-55_post_trial5']
# Processing file: E:\Donders\13\processed\Rat_OS_Ephys_Rat13_344994_SD13_OR_SD_N_13-14_06_2019\2019-06-13_09-53-03_presleep\2019-06-13_09-53-03_presleep_REM_dict.h5
# Available groups: ['2019-06-13_09-53-03_presleep']
# Processing file: E:\Donders\13\processed\Rat_OS_Ephys_Rat13_344994_SD13_OR_SD_N_13-14_06_2019\2019-06-13_10-44-46_post_trial1\2019-06-13_10-44-46_post_trial1_REM_dict.h5
# Available groups: ['2019-06-13_10-44-46_post_trial1']
# Processing file: E:\Donders\13\processed\Rat_OS_Ephys_Rat13_344994_SD13_OR_SD_N_13-14_06_2019\2019-06-13_11-35-44_post_trial2\2019-06-13_11-35-44_post_trial2_REM_dict.h5
# Available groups: ['2019-06-13_11-35-44_post_trial2']
# Processing file: E:\Donders\13\processed\Rat_OS_Ephys_Rat13_344994_SD13_OR_SD_N_13-14_06_2019\2019-06-13_12-26-56_post_trial3\2019-06-13_12-26-56_post_trial3_REM_dict.h5
# Available groups: ['2019-06-13_12-26-56_post_trial3']
# Processing file: E:\Donders\13\processed\Rat_OS_Ephys_Rat13_344994_SD13_OR_SD_N_13-14_06_2019\2019-06-13_13-18-09_post_trial4\2019-06-13_13-18-09_post_trial4_REM_dict.h5
# Available groups: ['2019-06-13_13-18-09_post_trial4']
# Processing file: E:\Donders\13\processed\Rat_OS_Ephys_Rat13_344994_SD13_OR_SD_N_13-14_06_2019\2019-06-13_14-40-49_post_trial5\2019-06-13_14-40-49_post_trial5_REM_dict.h5
# Available groups: ['2019-06-13_14-40-49_post_trial5']
# Processing file: E:\Donders\13\processed\Rat_OS_Ephys_Rat13_344994_SD2_HC_15_05_2019\2019-05-15_09-56-25_presleep\2019-05-15_09-56-25_presleep_REM_dict.h5
# Available groups: ['2019-05-15_09-56-25_presleep']
# Processing file: E:\Donders\13\processed\Rat_OS_Ephys_Rat13_344994_SD2_HC_15_05_2019\2019-05-15_10-47-11_post_trial1\2019-05-15_10-47-11_post_trial1_REM_dict.h5
# Available groups: ['2019-05-15_10-47-11_post_trial1']
# Processing file: E:\Donders\13\processed\Rat_OS_Ephys_Rat13_344994_SD2_HC_15_05_2019\2019-05-15_11-37-30_post_trial2\2019-05-15_11-37-30_post_trial2_REM_dict.h5
# Available groups: ['2019-05-15_11-37-30_post_trial2']
# (182500, 6)
# shape power matrix: (125, 182500)
# shape of fpp_plots (393, 125, 19)
# (125, 393)
# fpp_list length: 673
# (165000, 6)
# shape power matrix: (125, 165000)
# shape of fpp_plots (426, 125, 19)
# (125, 426)
# fpp_list length: 674
# (282500, 6)
# shape power matrix: (125, 282500)
# shape of fpp_plots (714, 125, 19)
# (125, 714)
# fpp_list length: 675
# (7500, 6)
# shape power matrix: (125, 7500)
# shape of fpp_plots (16, 125, 19)
# (125, 16)
# fpp_list length: 676
# Processing file: E:\Donders\13\processed\Rat_OS_Ephys_Rat13_344994_SD2_HC_15_05_2019\2019-05-15_12-27-45_post_trial3\2019-05-15_12-27-45_post_trial3_REM_dict.h5
# Available groups: ['2019-05-15_12-27-45_post_trial3']
# (225000, 6)
# shape power matrix: (125, 225000)
# shape of fpp_plots (479, 125, 19)
# (125, 479)
# fpp_list length: 677
# (92500, 6)
# shape power matrix: (125, 92500)
# shape of fpp_plots (188, 125, 19)
# (125, 188)
# fpp_list length: 678
# (390000, 6)
# shape power matrix: (125, 390000)
# shape of fpp_plots (844, 125, 19)
# (125, 844)
# fpp_list length: 679
# (2500, 6)
# shape power matrix: (125, 2500)
# shape of fpp_plots (4, 125, 19)
# (125, 4)
# fpp_list length: 680
# Processing file: E:\Donders\13\processed\Rat_OS_Ephys_Rat13_344994_SD2_HC_15_05_2019\2019-05-15_13-17-54_post_trial4\2019-05-15_13-17-54_post_trial4_REM_dict.h5
# Available groups: ['2019-05-15_13-17-54_post_trial4']
# (267500, 6)
# shape power matrix: (125, 267500)
# shape of fpp_plots (616, 125, 19)
# (125, 616)
# fpp_list length: 681
# (102500, 6)
# shape power matrix: (125, 102500)
# shape of fpp_plots (256, 125, 19)
# (125, 256)
# fpp_list length: 682
# Processing file: E:\Donders\13\processed\Rat_OS_Ephys_Rat13_344994_SD2_HC_15_05_2019\2019-05-15_14-08-14_post_trial5\2019-05-15_14-08-14_post_trial5_REM_dict.h5
# Available groups: ['2019-05-15_14-08-14_post_trial5']
# (222500, 6)
# shape power matrix: (125, 222500)
# shape of fpp_plots (637, 125, 19)
# (125, 637)
# fpp_list length: 683
# (160000, 6)
# shape power matrix: (125, 160000)
# shape of fpp_plots (481, 125, 19)
# (125, 481)
# fpp_list length: 684
# (232500, 6)
# shape power matrix: (125, 232500)
# shape of fpp_plots (644, 125, 19)
# (125, 644)
# fpp_list length: 685
# (227500, 6)
# shape power matrix: (125, 227500)
# shape of fpp_plots (669, 125, 19)
# (125, 669)
# fpp_list length: 686
# (60000, 6)
# shape power matrix: (125, 60000)
# shape of fpp_plots (146, 125, 19)
# (125, 146)
# fpp_list length: 687
# (20000, 6)
# shape power matrix: (125, 20000)
# shape of fpp_plots (44, 125, 19)
# (125, 44)
# fpp_list length: 688
# (255000, 6)
# shape power matrix: (125, 255000)
# shape of fpp_plots (745, 125, 19)
# (125, 745)
# fpp_list length: 689
# (92500, 6)
# shape power matrix: (125, 92500)
# shape of fpp_plots (261, 125, 19)
# (125, 261)
# fpp_list length: 690
# Processing file: E:\Donders\13\processed\Rat_OS_Ephys_Rat13_344994_SD3_OR_16-17_05_2019\2019-05-16_10-28-10_presleep\2019-05-16_10-28-10_presleep_REM_dict.h5
# Available groups: ['2019-05-16_10-28-10_presleep']
# Processing file: E:\Donders\13\processed\Rat_OS_Ephys_Rat13_344994_SD3_OR_16-17_05_2019\2019-05-16_11-18-59_post_trial1\2019-05-16_11-18-59_post_trial1_REM_dict.h5
# Available groups: ['2019-05-16_11-18-59_post_trial1']
# Processing file: E:\Donders\13\processed\Rat_OS_Ephys_Rat13_344994_SD3_OR_16-17_05_2019\2019-05-16_12-09-30_post_trial2\2019-05-16_12-09-30_post_trial2_REM_dict.h5
# Available groups: ['2019-05-16_12-09-30_post_trial2']
# (355000, 6)
# shape power matrix: (125, 355000)
# shape of fpp_plots (1002, 125, 19)
# (125, 1002)
# fpp_list length: 691
# (52500, 6)
# shape power matrix: (125, 52500)
# shape of fpp_plots (132, 125, 19)
# (125, 132)
# fpp_list length: 692
# (510000, 6)
# shape power matrix: (125, 510000)
# shape of fpp_plots (1348, 125, 19)
# (125, 1348)
# fpp_list length: 693
# Processing file: E:\Donders\13\processed\Rat_OS_Ephys_Rat13_344994_SD3_OR_16-17_05_2019\2019-05-16_13-00-09_post_trial3\2019-05-16_13-00-09_post_trial3_REM_dict.h5
# Available groups: ['2019-05-16_13-00-09_post_trial3']
# (247500, 6)
# shape power matrix: (125, 247500)
# shape of fpp_plots (664, 125, 19)
# (125, 664)
# fpp_list length: 694
# (130000, 6)
# shape power matrix: (125, 130000)
# shape of fpp_plots (336, 125, 19)
# (125, 336)
# fpp_list length: 695
# (210000, 6)
# shape power matrix: (125, 210000)
# shape of fpp_plots (564, 125, 19)
# (125, 564)
# fpp_list length: 696
# (295000, 6)
# shape power matrix: (125, 295000)
# shape of fpp_plots (559, 125, 19)
# (125, 559)
# fpp_list length: 697
# (112500, 6)
# shape power matrix: (125, 112500)
# shape of fpp_plots (299, 125, 19)
# (125, 299)
# fpp_list length: 698
# (42500, 6)
# shape power matrix: (125, 42500)
# shape of fpp_plots (80, 125, 19)
# (125, 80)
# fpp_list length: 699
# Processing file: E:\Donders\13\processed\Rat_OS_Ephys_Rat13_344994_SD3_OR_16-17_05_2019\2019-05-16_13-51-09_post_trial4\2019-05-16_13-51-09_post_trial4_REM_dict.h5
# Available groups: ['2019-05-16_13-51-09_post_trial4']
# (467500, 6)
# shape power matrix: (125, 467500)
# shape of fpp_plots (1292, 125, 19)
# (125, 1292)
# fpp_list length: 700
# (85000, 6)
# shape power matrix: (125, 85000)
# shape of fpp_plots (243, 125, 19)
# (125, 243)
# fpp_list length: 701
# (372500, 6)
# shape power matrix: (125, 372500)
# shape of fpp_plots (1080, 125, 19)
# (125, 1080)
# fpp_list length: 702
# Processing file: E:\Donders\13\processed\Rat_OS_Ephys_Rat13_344994_SD3_OR_16-17_05_2019\2019-05-16_14-41-48_post_trial5\2019-05-16_14-41-48_post_trial5_REM_dict.h5
# Available groups: ['2019-05-16_14-41-48_post_trial5']
# (267500, 6)
# shape power matrix: (125, 267500)
# shape of fpp_plots (530, 125, 19)
# (125, 530)
# fpp_list length: 703
# (122500, 6)
# shape power matrix: (125, 122500)
# shape of fpp_plots (277, 125, 19)
# (125, 277)
# fpp_list length: 704
# (212500, 6)
# shape power matrix: (125, 212500)
# shape of fpp_plots (384, 125, 19)
# (125, 384)
# fpp_list length: 705
# (242500, 6)
# shape power matrix: (125, 242500)
# shape of fpp_plots (445, 125, 19)
# (125, 445)
# fpp_list length: 706
# (72500, 6)
# shape power matrix: (125, 72500)
# shape of fpp_plots (159, 125, 19)
# (125, 159)
# fpp_list length: 707
# (215000, 6)
# shape power matrix: (125, 215000)
# shape of fpp_plots (417, 125, 19)
# (125, 417)
# fpp_list length: 708
# (330000, 6)
# shape power matrix: (125, 330000)
# shape of fpp_plots (722, 125, 19)
# (125, 722)
# fpp_list length: 709
# Processing file: E:\Donders\13\processed\Rat_OS_Ephys_Rat13_344994_SD4_OD_21-22_05_2019\2019-05-21_10-38-24_presleep\2019-05-21_10-38-24_presleep_REM_dict.h5
# Available groups: ['2019-05-21_10-38-24_presleep']
# Processing file: E:\Donders\13\processed\Rat_OS_Ephys_Rat13_344994_SD4_OD_21-22_05_2019\2019-05-21_11-29-11_post_trial1\2019-05-21_11-29-11_post_trial1_REM_dict.h5
# Available groups: ['2019-05-21_11-29-11_post_trial1']
# Processing file: E:\Donders\13\processed\Rat_OS_Ephys_Rat13_344994_SD4_OD_21-22_05_2019\2019-05-21_12-19-45_post_trial2\2019-05-21_12-19-45_post_trial2_REM_dict.h5
# Available groups: ['2019-05-21_12-19-45_post_trial2']
# Processing file: E:\Donders\13\processed\Rat_OS_Ephys_Rat13_344994_SD4_OD_21-22_05_2019\2019-05-21_13-11-00_post_trial3\2019-05-21_13-11-00_post_trial3_REM_dict.h5
# Available groups: ['2019-05-21_13-11-00_post_trial3']
# Processing file: E:\Donders\13\processed\Rat_OS_Ephys_Rat13_344994_SD4_OD_21-22_05_2019\2019-05-21_14-01-51_post_trial4\2019-05-21_14-01-51_post_trial4_REM_dict.h5
# Available groups: ['2019-05-21_14-01-51_post_trial4']
# Processing file: E:\Donders\13\processed\Rat_OS_Ephys_Rat13_344994_SD4_OD_21-22_05_2019\2019-05-21_14-56-02_post_trial5\2019-05-21_14-56-02_post_trial5_REM_dict.h5
# Available groups: ['2019-05-21_14-56-02_post_trial5']
# (207500, 6)
# shape power matrix: (125, 207500)
# shape of fpp_plots (501, 125, 19)
# (125, 501)
# fpp_list length: 710
# (55000, 6)
# shape power matrix: (125, 55000)
# shape of fpp_plots (151, 125, 19)
# (125, 151)
# fpp_list length: 711
# (10000, 6)
# shape power matrix: (125, 10000)
# shape of fpp_plots (26, 125, 19)
# (125, 26)
# fpp_list length: 712
# (347500, 6)
# shape power matrix: (125, 347500)
# shape of fpp_plots (1011, 125, 19)
# (125, 1011)
# fpp_list length: 713
# (202500, 6)
# shape power matrix: (125, 202500)
# shape of fpp_plots (606, 125, 19)
# (125, 606)
# fpp_list length: 714
# (355000, 6)
# shape power matrix: (125, 355000)
# shape of fpp_plots (1061, 125, 19)
# (125, 1061)
# fpp_list length: 715
# (260000, 6)
# shape power matrix: (125, 260000)
# shape of fpp_plots (716, 125, 19)
# (125, 716)
# fpp_list length: 716
# (75000, 6)
# shape power matrix: (125, 75000)
# shape of fpp_plots (223, 125, 19)
# (125, 223)
# fpp_list length: 717
# (317500, 6)
# shape power matrix: (125, 317500)
# shape of fpp_plots (926, 125, 19)
# (125, 926)
# fpp_list length: 718
# (340000, 6)
# shape power matrix: (125, 340000)
# shape of fpp_plots (971, 125, 19)
# (125, 971)
# fpp_list length: 719
# (72500, 6)
# shape power matrix: (125, 72500)
# shape of fpp_plots (202, 125, 19)
# (125, 202)
# fpp_list length: 720
# combined_fpp shape is (298536, 125, 19)
# (125, 298536)

# %%
#Plotting the spectral signature of each cycle individually

# Plot each row in one plot
for i in range(power_array.shape[0]):
    plt.plot(frequency_array, power_array.T[i, :], label=f'Row {i + 1}')

# Add labels and legend
plt.xlabel('Frequency [Hz]')
plt.ylabel('Power')
plt.title(f'Spectral Signature for each cycle z-scored - Rat: {target_folders}')

# Show the plot

plt.show()

# Calculate the mean power across all cycles
spectral_signature_mean = np.mean(power_array.T, axis=0)

# Calculate the standard deviation across all cycles (instead of standard error of the mean)
spectral_signature_std = np.std(power_array.T, axis=0)

# Plot the mean power across all cycles
plt.plot(frequency_array, spectral_signature_mean, linestyle='-', color='blue', label='Mean Spectral Signature')

# Fill the area between mean - std and mean + std with a translucent color
plt.fill_between(frequency_array, spectral_signature_mean - spectral_signature_std, spectral_signature_mean + spectral_signature_std, color='lightblue', alpha=0.3, label='Standard Deviation of Spectral Signature')

plt.xlabel('Frequency [Hz]')
plt.ylabel('Power')
plt.title(f'Spectral Signature z-scored - Rat: {target_folders}')

# Place the legend outside of the plot
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

np.save(r'E:\Donders\Weekly meeting\PCA_ICA\power_array_non_zscored.npy', power_array)

# %%
# Load the saved power array
power_array = np.load(r'E:\Donders\Weekly meeting\PCA_ICA\power_array_non_zscored.npy')

# %%
print(power_array.shape)
# Out:
# (125, 298536)

# %%
#PCA
seed=12
print(power_array.shape)
scaler = StandardScaler()
normalized_power_array = scaler.fit_transform(power_array)
pca=PCA(n_components=0.85,whiten=False,svd_solver='full', random_state=seed)
pcv=pca.fit_transform(normalized_power_array.T)#15-120Hz
print('Principal Component Analysis yields us '+str(pca.n_components_) + ' principal components')
print(pcv.shape)
#Explained variance ratio of ICA
print("Explained Variance Ratio:", pca.explained_variance_ratio_)
# Out:
# (125, 298536)
# Principal Component Analysis yields us 7 principal components
# (298536, 7)
# Explained Variance Ratio: [0.30364526 0.17377739 0.11621772 0.09652697 0.07424364 0.05650765
#  0.04329121]

# %%
#ICA
ica = FastICA(n_components=pca.n_components_, whiten='unit-variance', random_state=seed)
icv = ica.fit_transform(power_array.T)
print(icv.shape)
# Out:
# (298536, 7)

# %%
#Classifying cycles into identified components

tSCs_median=np.median(icv,axis=0) # median(p)

print('tSC medians:'+ str(tSCs_median)+'\n')
mask=np.logical_and(icv>=tSCs_median,icv>0) # boolean values that satisfy |p-median(p)|
threshold=[]
for icvs,bl,tscmed in zip(icv.T,mask.T,tSCs_median):
    threshold.append(2*np.std(icvs[bl])+tscmed) # corrected code
thresholdmedian=np.array(threshold)
print('Calculated thresholds:'+str(thresholdmedian)+'\n')
tSCmask=icv>thresholdmedian #boolean array of satisfactory strong tSC components
for t,(icvT,tSCT) in enumerate(zip(icv.T,tSCmask.T)):
    print('#tSC'+str(t+1)+ ' cycles:'+str(icvT[tSCT].shape[0])+',\n')
print('Total number of tSC cycles detected: '+str(icv[tSCmask].shape[0]))

# Filter fpp_list based on the identified components
#filtered_fpp_list = [fpp_plot for fpp_plot, mask in zip(fpp_list, tSCmask) if len(fpp_plot.shape) > 0]
# Access fpp_plot for cycles within identified components
#fpp_plots_in_components = [fpp_plot[mask] for fpp_plot, mask in zip(filtered_fpp_list, tSCmask)]
#print(fpp_plots_in_components.shape)
# Out:
# tSC medians:[ 0.2426818  -0.07266377  0.18867109 -0.00447127 -0.12292442  0.16990767
#   0.0143019 ]
#
# Calculated thresholds:[0.82353844 3.67185564 1.24077503 1.90257376 4.49142692 0.94831729
#  1.5010797 ]
#
# #tSC1 cycles:9377,
#
# #tSC2 cycles:2661,
#
# #tSC3 cycles:5825,
#
# #tSC4 cycles:4462,
#
# #tSC5 cycles:1882,
#
# #tSC6 cycles:5132,
#
# #tSC7 cycles:10250,
#
# Total number of tSC cycles detected: 39589

# %%
# Set the number of bins
n_bins = 500

# Set plot parameters
mediancolor = 'black'
medianlinestyle = 'dashed'
plt.rcParams.update({'font.size': 15})

# Create a legend labels list
legend_labels = ['Median', 'Threshold']

for i in range(icv.shape[1]):
    fig, ax = plt.subplots(figsize=(10, 7))
    fig.suptitle(f'tSC{i + 1} Distribution calculated from Power(z) cycles 15-140 Hz')
    
    # Plot histogram
    ax.hist(icv[:, i], bins=n_bins, histtype='bar', fill=False, density=True, edgecolor='lightblue', label='Distribution')
    
    # Plot median line
    ax.plot((np.median(icv[:, i]), np.median(icv[:, i])), (0, 0.3), color=mediancolor, linestyle='dashed', label=legend_labels[0])

    # Plot threshold line
    ax.plot((thresholdmedian[i], thresholdmedian[i]), (0, 0.3), color='red', label=legend_labels[1])

    ax.set_title(f'tSC{i + 1}')

    # Add legend
    ax.legend()

    # Adjust layout for better spacing
    plt.tight_layout(rect=[0, 0, 1, 0.97])

    # Show the plot
    plt.show()

# %%
print(tSCmask.shape)
#@title Spectral Signatures of tSC cycles
tSC1=power_array.T[tSCmask.T[0]]
tSC2=power_array.T[tSCmask.T[1]]
tSC3=power_array.T[tSCmask.T[2]]
tSC4=power_array.T[tSCmask.T[3]]
tSC5=power_array.T[tSCmask.T[4]]
tSC6=power_array.T[tSCmask.T[5]]
tSC7=power_array.T[tSCmask.T[6]]



fig18,ax18=plt.subplots(1,icv.shape[1],figsize=(30,7))
plt.rcParams.update({'font.size': 15})
ax18[0].plot(tSC1.mean(axis=0),np.arange(15,140,1),color='blue',linestyle='dashed',
              label='tSC1 mean')
ax18[0].fill_betweenx(np.arange(15,140,1),
                       -tSC1.std(axis=0)+tSC1.mean(axis=0),
                       tSC1.std(axis=0)+tSC1.mean(axis=0),
                       alpha=0.2,color='blue')
ax18[0].set_xlabel('Power [μV²]')
ax18[0].set_ylabel('Frequency[Hz]')
ax18[0].legend(loc='upper right')
ax18[0].set_title('tSC1') 
ax18[1].plot(tSC2.mean(axis=0),np.arange(15,140,1),color='green',linestyle='dashed',
              label='tSC2 mean')
ax18[1].fill_betweenx(np.arange(15,140,1),
                       -tSC2.std(axis=0)+tSC2.mean(axis=0),
                       tSC2.std(axis=0)+tSC2.mean(axis=0),
                       alpha=0.2,color='green')
ax18[1].set_xlabel('Power Weight [μV²]')
#ax18[1].set_ylabel('Frequency')
ax18[1].legend(loc='upper right')
ax18[1].set_title('tSC2') 
ax18[2].plot(tSC3.mean(axis=0),np.arange(15,140,1),color='orange',linestyle='dashed',
              label='tSC3 mean')
ax18[2].fill_betweenx(np.arange(15,140,1),
                       -tSC3.std(axis=0)+tSC3.mean(axis=0),
                       tSC3.std(axis=0)+tSC3.mean(axis=0),
                       alpha=0.2,color='orange')
ax18[2].set_xlabel('Power Weight [μV²]')
#ax18[2].set_ylabel('Frequency')
ax18[2].legend(loc='upper right')
ax18[2].set_title('tSC3') 
ax18[3].plot(tSC4.mean(axis=0),np.arange(15,140,1),color='pink',linestyle='dashed',
              label='tSC4 mean')
ax18[3].fill_betweenx(np.arange(15,140,1),
                       -tSC4.std(axis=0)+tSC4.mean(axis=0),
                       tSC4.std(axis=0)+tSC4.mean(axis=0),
                       alpha=0.2,color='pink')
ax18[3].set_xlabel('Power Weight [μV²]')
#ax18[3].set_ylabel('Frequency')
ax18[3].legend(loc='upper right')
ax18[3].set_title('tSC4') 
ax18[4].plot(tSC5.mean(axis=0),np.arange(15,140,1),color='violet',linestyle='dashed',
              label='tSC5 mean')
ax18[4].fill_betweenx(np.arange(15,140,1),
                       -tSC5.std(axis=0)+tSC5.mean(axis=0),
                       tSC5.std(axis=0)+tSC5.mean(axis=0),
                       alpha=0.2,color='violet')
ax18[4].set_xlabel('Power Weight [μV²]')
#ax18[4].set_ylabel('Frequency')
ax18[4].legend(loc='upper right')
ax18[4].set_title('tSC5') 
ax18[5].plot(tSC6.mean(axis=0),np.arange(15,140,1),color='red',linestyle='dashed',
              label='tSC6 mean')
ax18[5].fill_betweenx(np.arange(15,140,1),
                       -tSC6.std(axis=0)+tSC6.mean(axis=0),
                       tSC6.std(axis=0)+tSC6.mean(axis=0),
                       alpha=0.2,color='red')
ax18[5].set_xlabel('Power Weight [μV²]')
#ax18[5].set_ylabel('Frequency')
ax18[5].legend(loc='upper right')
ax18[5].set_title('tSC6') 
ax18[6].plot(tSC7.mean(axis=0),np.arange(15,140,1),color='brown',linestyle='dashed',
              label='tSC7 mean')
ax18[6].fill_betweenx(np.arange(15,140,1),
                       -tSC7.std(axis=0)+tSC7.mean(axis=0),
                       tSC7.std(axis=0)+tSC7.mean(axis=0),
                       alpha=0.2,color='brown')
ax18[6].set_xlabel('Power Weight [μV²]')
#ax18[6].set_ylabel('Frequency')
ax18[6].legend(loc='upper right')
ax18[6].set_title('tSC7')
# Out:
# (298536, 7)
# Text(0.5, 1.0, 'tSC7')

# %%
import os
import glob
import h5py
import pandas as pd
import numpy as np

root_folder = r"E:\Donders"

# Define the target folders
target_folders = ['1', '3', '4', '9', '11', '13']
table_data = []

# Initialize an empty list to store the boolean mask for each file
tSCmask_list = []

for target_folder in target_folders:
    # Construct the path to the processed folders
    processed_folder = os.path.join(root_folder, target_folder, 'processed')

    # Iterate through subfolders in processed folder
    for subfolder in os.listdir(processed_folder):
        subfolder_path = os.path.join(processed_folder, subfolder)

        # Check if it's a directory
        if os.path.isdir(subfolder_path):
            # Iterate through sub-subfolders (containing datasets)
            for dataset_folder in os.listdir(subfolder_path):
                dataset_folder_path = os.path.join(subfolder_path, dataset_folder)

                # Check if it's a directory
                if os.path.isdir(dataset_folder_path):
                    # Use glob to get all .h5 files in the dataset folder
                    hdf5_files = glob.glob(os.path.join(dataset_folder_path, '*.h5'))

                    # Iterate over each .h5 file
                    for hdf5_file_path in hdf5_files:
                        # Open the HDF5 file in read mode
                        with h5py.File(hdf5_file_path, 'r') as hdf_file:
                            # Iterate over all groups in the file
                            for group_name in hdf_file.keys():
                                # Access the current group
                                current_group = hdf_file[group_name]

                                # Continue with your processing for the current group
                                rem_dict_keys = list(current_group.keys())

                                for rem_key in rem_dict_keys:
                                    # Check if 'Cycles' key exists and is not empty
                                    if 'Cycles' in current_group[rem_key] and len(current_group[rem_key]['Cycles']) > 0:
                                        # Access the 'Cycles' key to get the start and end indices
                                        cycles = current_group[rem_key]['Cycles']

                                        # Use NumPy operations to extract indices
                                        start_indices = np.array([cycle[0] for cycle in cycles])
                                        end_indices = np.array([cycle[-1] for cycle in cycles])

                                        # Append data to table_data
                                        table_data.extend([(target_folder, subfolder, dataset_folder, rem_key, start, end) for start, end in zip(start_indices, end_indices)])

                                        # Assuming tSCmask is calculated here and has the shape (len(start_indices), 7)
                                        # Modify this line based on how tSCmask is obtained in your code
                                        tSCmask_list.append(tSCmask)

# Create a DataFrame from the collected data
columns = ['RatNumber', 'BehavioralMode', 'DatasetName', 'REM', 'StartIndex', 'EndIndex']
df = pd.DataFrame(table_data, columns=columns)

# Determine the number of components
num_components = tSCmask.shape[1]

# Generate column names dynamically
column_names = [f'tSC{i}' for i in range(1, num_components + 1)]

# Concatenate tSCmask with the existing DataFrame
df_with_mask = pd.concat([df, pd.DataFrame(tSCmask, columns=column_names)], axis=1)

# Add a new column to indicate if multiple tSCs are True for each cycle
df_with_mask['MultipleTrue'] = df_with_mask.iloc[:, -num_components:].sum(axis=1) > 1

# Check if there are cycles with True values in multiple tSCs
cycles_with_multiple_true = df_with_mask[df_with_mask['MultipleTrue']]

# Print the cycles with True values in multiple tSCs
print("Cycles with True values in multiple tSCs:")
print(cycles_with_multiple_true[['RatNumber', 'BehavioralMode', 'DatasetName', 'REM', 'StartIndex', 'EndIndex']])

csv_filename = r"E:\Donders\df4_table_all_rats_with_mask.csv"
df_with_mask.to_csv(csv_filename, index=True, sep='\t', encoding='utf-8')

# Print the DataFrame with the added columns
print(df_with_mask)
# Out:
# Cycles with True values in multiple tSCs:
#        RatNumber                                  BehavioralMode  \
# 11717          1                                              CN
# 11821          1                                              CN
# 18648          1                                              HC
# 20107          1                                              HC
# 24012          1                                              OD
# ...          ...                                             ...
# 298424        13  Rat_OS_Ephys_Rat13_344994_SD4_OD_21-22_05_2019
# 298440        13  Rat_OS_Ephys_Rat13_344994_SD4_OD_21-22_05_2019
# 298479        13  Rat_OS_Ephys_Rat13_344994_SD4_OD_21-22_05_2019
# 298482        13  Rat_OS_Ephys_Rat13_344994_SD4_OD_21-22_05_2019
# 298492        13  Rat_OS_Ephys_Rat13_344994_SD4_OD_21-22_05_2019
#
#                             DatasetName    REM  StartIndex  EndIndex
# 11717   post_trial5_2017-09-28_14-55-18  REM 9    14395316  14395613
# 11821   post_trial5_2017-09-28_14-55-18  REM 9    14433419  14433678
# 18648   post_trial5_2017-09-27_14-18-24  REM 3    10008259  10008577
# 20107   post_trial5_2017-09-27_14-18-24  REM 7    14461857  14462078
# 24012   post_trial2_2017-09-21_11-57-34  REM 2     5054644   5054856
# ...                                 ...    ...         ...       ...
# 298424  2019-05-21_14-56-02_post_trial5  REM 9    15125099  15125423
# 298440  2019-05-21_14-56-02_post_trial5  REM 9    15130123  15130433
# 298479  2019-05-21_14-56-02_post_trial5  REM 9    15143528  15143882
# 298482  2019-05-21_14-56-02_post_trial5  REM 9    15145234  15145501
# 298492  2019-05-21_14-56-02_post_trial5  REM 9    15148784  15149109
#
# [9491 rows x 6 columns]
#        RatNumber                                  BehavioralMode  \
# 0              1                                              CN
# 1              1                                              CN
# 2              1                                              CN
# 3              1                                              CN
# 4              1                                              CN
# ...          ...                                             ...
# 298531        13  Rat_OS_Ephys_Rat13_344994_SD4_OD_21-22_05_2019
# 298532        13  Rat_OS_Ephys_Rat13_344994_SD4_OD_21-22_05_2019
# 298533        13  Rat_OS_Ephys_Rat13_344994_SD4_OD_21-22_05_2019
# 298534        13  Rat_OS_Ephys_Rat13_344994_SD4_OD_21-22_05_2019
# 298535        13  Rat_OS_Ephys_Rat13_344994_SD4_OD_21-22_05_2019
#
#                             DatasetName    REM  StartIndex  EndIndex   tSC1  \
# 0       post_trial1_2017-09-28_11-30-59  REM 1     5412714   5413007  False
# 1       post_trial1_2017-09-28_11-30-59  REM 1     5413007   5413361  False
# 2       post_trial1_2017-09-28_11-30-59  REM 1     5413361   5413739  False
# 3       post_trial1_2017-09-28_11-30-59  REM 1     5413739   5414123  False
# 4       post_trial1_2017-09-28_11-30-59  REM 1     5414123   5414456  False
# ...                                 ...    ...         ...       ...    ...
# 298531  2019-05-21_14-56-02_post_trial5  REM 9    15162151  15162359  False
# 298532  2019-05-21_14-56-02_post_trial5  REM 9    15162878  15163358  False
# 298533  2019-05-21_14-56-02_post_trial5  REM 9    15163726  15164130  False
# 298534  2019-05-21_14-56-02_post_trial5  REM 9    15164130  15164449  False
# 298535  2019-05-21_14-56-02_post_trial5  REM 9    15164449  15164853  False
#
#          tSC2   tSC3   tSC4   tSC5   tSC6   tSC7  MultipleTrue
# 0       False  False  False  False  False  False         False
# 1       False  False  False  False  False  False         False
# 2       False  False  False  False  False  False         False
# 3       False  False  False  False  False  False         False
# 4       False  False  False  False  False  False         False
# ...       ...    ...    ...    ...    ...    ...           ...
# 298531  False  False  False  False  False  False         False
# 298532  False  False  False  False  False  False         False
# 298533  False  False  False  False  False  False         False
# 298534  False  False  False  False  False  False         False
# 298535  False  False  False  False  False  False         False
#
# [298536 rows x 14 columns]
