# %%
from src.utils.DataFolder import DataFolder
from src.Signal import Signal
from src.ThetaSignal import ThetaSignal
from src.utils.helper import load_config
from src.pipeline import emd_analysis

import numpy as np
import pandas as pd

data_path = "/home/miranjo/phasic_tonic/data/processed"
config_path = "/home/miranjo/phasic_tonic/configs/test.yaml"

# %% [markdown]
# ### Loading the arguments

# %%
args = load_config(config_path)

fs = args.pop("fs", 2500)
f_theta = (args.pop("f_theta_lower", 4), args.pop("f_theta_upper", 12))
f_lowpass = args.pop("f_lowpass", 25)
n_seconds_filter = args.pop("n_seconds_filter", 0.5)
n_seconds_theta = args.pop("n_seconds_theta", 0.75)

threshold_kwargs = args.pop("threshold_kwargs", None)

# %%
remFolder = DataFolder(data_path)
print(remFolder)
# Out:
# DataFolder in '/home/miranjo/phasic_tonic/data/processed', contains 102 files.

# %%
sample = remFolder[3]
lfpREM = sample["data"][0]
metadata = sample["metadata"]

sig = Signal(lfpREM, fs)
sig.filter('bandpass', f_theta, n_seconds_theta)
sig.plot(xlim=(0, 1.5))

# %%
metadata
# Out:
# {'RatID': 'Rat4',
#  'StudyDay': 'SD9',
#  'condition': 'HC',
#  'condition_full': 'HomeCage',
#  'treatment': 'TreatmentNegative',
#  'posstrial_number': 'posttrial3'}

# %%
theta = ThetaSignal(lfpREM, fs)
theta.filter('bandpass', f_theta, n_seconds_theta)
theta.segment_cycles()
# Out:
# Phasic periods in the bandpass signal: 47
# Periods:
#  [(106769, 108987), (125289, 127831), (171562, 174662), (267133, 272945)]
# Tonic periods in the bandpass signal: 865
# Periods:
#  [(333, 125289), (127831, 171562), (174662, 267133), (269655, 269888), (272945, 305444)]

# %%
sig = ThetaSignal(remFolder[3]["data"][0], 2500)
sig.summary()
# Out:
# Sampling rate: 2500 Hz
# Duration: 122.20 seconds
# Max value: 665.82 uV
# Min value: -461.92 uV
# Mean value: -0.00 uV
# Standard Deviation: 159.80 uV
# Signal Range: 1127.73 uV
# Number of Data Points: 305495

# %%
sig.filter('bandpass', f_theta, n_seconds_theta)
sig.segment_cycles()
# Out:
# Phasic periods in the bandpass signal: 47
# Periods:
#  [(106769, 108987), (125289, 127831), (171562, 174662), (267133, 272945)]
# Tonic periods in the bandpass signal: 865
# Periods:
#  [(333, 125289), (127831, 171562), (174662, 267133), (269655, 269888), (272945, 305444)]

# %%
dfs = []
for tonic in sig.get_tonic():
    df = emd_analysis(tonic, 2500)
    break
# Out:
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (380 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 349

# %%
bins = np.arange(0.2, 0.8, 0.01)

oc_hist_phasic = [np.zeros(len(bins)-1, dtype=np.int64), np.zeros(len(bins)-1, dtype=np.int64)]
hc_hist_phasic = [np.zeros(len(bins)-1, dtype=np.int64), np.zeros(len(bins)-1, dtype=np.int64)]
oc_hist_tonic = [np.zeros(len(bins)-1, dtype=np.int64), np.zeros(len(bins)-1, dtype=np.int64)]
hc_hist_tonic = [np.zeros(len(bins)-1, dtype=np.int64), np.zeros(len(bins)-1, dtype=np.int64)]

for sample in remFolder:
    lfpREMs = sample["data"]
    metadata = sample["metadata"]

    condition = metadata["condition"]
    treatment = metadata["treatment"]

    for lfpREM in lfpREMs:
        theta = ThetaSignal(lfpREM, fs)
        if(theta.duration >= 1875/2500):
            theta.filter('lowpass', f_theta, n_seconds_filter)
            theta.segment_cycles()
        else:
            break
        
        for tonic in theta.get_tonic():
            df = emd_analysis(tonic, theta.sampling_rate)

            hist_a2d, _ = np.histogram(df["asc2desc"], bins=bins)
            hist_p2t, _ = np.histogram(df["peak2trough"], bins=bins)

            if(condition == 'HC'):
                hc_hist_tonic[0] += hist_a2d
                hc_hist_tonic[1] += hist_p2t
            else:
                oc_hist_tonic[0] += hist_a2d
                oc_hist_tonic[1] += hist_p2t
        
        if(theta.phasic == None):
            break
        
        for phasic in theta.get_phasic():
            df = emd_analysis(phasic, theta.sampling_rate)

            hist_a2d, _ = np.histogram(df["asc2desc"], bins=bins)
            hist_p2t, _ = np.histogram(df["peak2trough"], bins=bins)

            if(condition == 'HC'):
                hc_hist_phasic[0] += hist_a2d
                hc_hist_phasic[1] += hist_p2t
            else:
                oc_hist_phasic[0] += hist_a2d
                oc_hist_phasic[1] += hist_p2t
# Out:
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 663
# Periods:
#  [(293, 209426)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (621 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 518
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 1144
# Periods:
#  [(405, 386983)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (1111 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 950
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 748
# Periods:
#  [(139, 243773)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (716 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 571
# Phasic periods in the lowpass signal: 37
# Periods:
#  [(106769, 108988), (171557, 174665), (267131, 272657)]
# Tonic periods in the lowpass signal: 873
# Periods:
#  [(332, 171557), (174665, 267131), (269656, 269885), (272657, 305452)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (523 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 487
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (263 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 249
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (2 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 0
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (93 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 75
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (12 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 10
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (20 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 17
# Phasic periods in the lowpass signal: 16
# Periods:
#  [(144585, 146905), (347231, 349359)]
# Tonic periods in the lowpass signal: 1084
# Periods:
#  [(370, 365124)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (1096 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 1010
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 165
# Periods:
#  [(364, 50388)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (158 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 124
# Phasic periods in the lowpass signal: 8
# Periods:
#  [(696412, 698802)]
# Tonic periods in the lowpass signal: 8261
# Periods:
#  [(224, 2868921)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (6615 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 4048
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 6
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 175
# Periods:
#  [(354, 55150)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (168 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 135
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 203
# Periods:
#  [(310, 67217)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (205 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 180
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 605
# Periods:
#  [(321, 203060)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (592 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 519
# Phasic periods in the lowpass signal: 9
# Periods:
#  [(122352, 124860)]
# Tonic periods in the lowpass signal: 775
# Periods:
#  [(169, 122352), (124860, 254961)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (379 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 348
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (391 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 370
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 423
# Periods:
#  [(229, 143843)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (413 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 353
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 506
# Periods:
#  [(421, 164142)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (444 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 349
# Phasic periods in the lowpass signal: 21
# Periods:
#  [(105833, 108631), (150036, 153361)]
# Tonic periods in the lowpass signal: 562
# Periods:
#  [(513, 105833), (108631, 150036), (153361, 189191)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (322 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 298
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (134 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 121
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (103 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 95
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (12 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 10
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 171
# Periods:
#  [(506, 55979)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (171 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 165
# Phasic periods in the lowpass signal: 8
# Periods:
#  [(158801, 161206)]
# Tonic periods in the lowpass signal: 1103
# Periods:
#  [(198, 376946)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (1101 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 991
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 11
# Periods:
#  [(261, 3999)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (12 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Phasic periods in the lowpass signal: 10
# Periods:
#  [(145700, 148935)]
# Tonic periods in the lowpass signal: 1121
# Periods:
#  [(152, 145700), (148935, 384480)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (390 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 311
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (592 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 428
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 674
# Periods:
#  [(143, 218236)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (590 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 427
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 423
# Periods:
#  [(511, 138294)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (390 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 321
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 218
# Periods:
#  [(393, 74971)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (215 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 185
# Phasic periods in the lowpass signal: 8
# Periods:
#  [(140377, 143051)]
# Tonic periods in the lowpass signal: 1036
# Periods:
#  [(350, 140377), (143051, 357327)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (422 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 379
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (596 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 502
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 6
# Phasic periods in the lowpass signal: 8
# Periods:
#  [(21811, 24489)]
# Tonic periods in the lowpass signal: 634
# Periods:
#  [(255, 21811), (24489, 213309)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (64 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 57
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (572 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 505
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 266
# Periods:
#  [(555, 88472)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (259 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 228
# Phasic periods in the lowpass signal: 24
# Periods:
#  [(55297, 59346), (105307, 108165)]
# Tonic periods in the lowpass signal: 858
# Periods:
#  [(159, 55297), (59346, 105307), (108165, 295715)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (172 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 160
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (140 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 130
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (544 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 499
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (14 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 12
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (12 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 10
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 454
# Periods:
#  [(397, 151066)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (450 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 404
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 38
# Periods:
#  [(289, 12932)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (40 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 34
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 27
# Periods:
#  [(252, 8519)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (25 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 17
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 700
# Periods:
#  [(217, 241199)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (710 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 603
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 1141
# Periods:
#  [(329, 382560)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (1035 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 820
# Phasic periods in the lowpass signal: 30
# Periods:
#  [(49424, 52098), (162684, 165564), (175796, 178878)]
# Tonic periods in the lowpass signal: 803
# Periods:
#  [(187, 49424), (52098, 162684), (165564, 175796), (178878, 271397)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (150 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 138
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (342 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 320
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (31 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 26
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (278 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 260
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (12 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Phasic periods in the lowpass signal: 39
# Periods:
#  [(67886, 70036), (116075, 120239), (141147, 146297)]
# Tonic periods in the lowpass signal: 617
# Periods:
#  [(333, 116075), (120239, 141147), (146297, 215181)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (357 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 328
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (66 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 59
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (198 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 181
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (15 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 13
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (18 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 15
# Phasic periods in the lowpass signal: 27
# Periods:
#  [(64050, 66534), (182672, 184964), (307640, 310787)]
# Tonic periods in the lowpass signal: 974
# Periods:
#  [(315, 307640), (310787, 332703)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (924 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 850
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (65 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 57
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 42
# Periods:
#  [(192, 11619)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (43 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 39
# Phasic periods in the lowpass signal: 8
# Periods:
#  [(120885, 123091)]
# Tonic periods in the lowpass signal: 522
# Periods:
#  [(316, 166023)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (530 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 494
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Phasic periods in the lowpass signal: 8
# Periods:
#  [(32384, 34590)]
# Tonic periods in the lowpass signal: 443
# Periods:
#  [(381, 148211)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (446 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 412
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Phasic periods in the lowpass signal: 9
# Periods:
#  [(272343, 274901)]
# Tonic periods in the lowpass signal: 828
# Periods:
#  [(380, 272343), (274901, 280622)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (761 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 625
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (19 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 14
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Phasic periods in the lowpass signal: 9
# Periods:
#  [(119437, 121842)]
# Tonic periods in the lowpass signal: 618
# Periods:
#  [(415, 204454)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (584 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 482
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 39
# Periods:
#  [(484, 13677)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (36 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 18
# Phasic periods in the lowpass signal: 75
# Periods:
#  [(65355, 68258), (83497, 86796), (340195, 342628), (345829, 349181), (375479, 378240), (441042, 443361), (486257, 489012), (512436, 514775)]
# Tonic periods in the lowpass signal: 1511
# Periods:
#  [(365, 65355), (68258, 83497), (86796, 345829), (349181, 375479), (378240, 486257), (489012, 525709)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (209 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 191
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (43 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 35
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (753 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 615
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (86 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 79
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (315 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 295
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (107 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 96
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (12 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 10
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (13 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 11
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Phasic periods in the lowpass signal: 17
# Periods:
#  [(96178, 98966), (158124, 160561)]
# Tonic periods in the lowpass signal: 920
# Periods:
#  [(170, 96178), (98966, 303366)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (306 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 268
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (618 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 551
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Phasic periods in the lowpass signal: 9
# Periods:
#  [(39615, 42225)]
# Tonic periods in the lowpass signal: 190
# Periods:
#  [(549, 39615), (42225, 61124)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (125 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 112
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (66 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 57
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Phasic periods in the lowpass signal: 38
# Periods:
#  [(209062, 211973), (233234, 237206), (247044, 249359), (253455, 255612)]
# Tonic periods in the lowpass signal: 803
# Periods:
#  [(241, 209062), (211973, 233234), (237206, 278467)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (631 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 586
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (61 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 57
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (125 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 100
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (14 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 12
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Phasic periods in the lowpass signal: 10
# Periods:
#  [(15863, 19017)]
# Tonic periods in the lowpass signal: 116
# Periods:
#  [(153, 15863), (19017, 41302)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (51 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 40
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (68 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 62
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Phasic periods in the lowpass signal: 8
# Periods:
#  [(84388, 86645)]
# Tonic periods in the lowpass signal: 346
# Periods:
#  [(154, 119788)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (355 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 324
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Phasic periods in the lowpass signal: 28
# Periods:
#  [(214138, 216435), (227584, 230664), (298085, 300812)]
# Tonic periods in the lowpass signal: 963
# Periods:
#  [(175, 227584), (230664, 298085), (300812, 325353)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (692 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 659
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (209 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 197
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (74 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 65
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (12 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 10
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 161
# Periods:
#  [(148, 54010)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (164 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 145
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 614
# Periods:
#  [(367, 206779)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (589 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 461
# Phasic periods in the lowpass signal: 60
# Periods:
#  [(133768, 136267), (188415, 197698), (212594, 215378), (243005, 245641), (274119, 277049)]
# Tonic periods in the lowpass signal: 868
# Periods:
#  [(329, 188415), (193176, 212594), (215378, 243005), (245641, 274119), (277049, 311332)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (561 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 517
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (62 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 57
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (80 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 73
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (78 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 69
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (101 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 92
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (32 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 27
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Phasic periods in the lowpass signal: 9
# Periods:
#  [(19750, 22295)]
# Tonic periods in the lowpass signal: 958
# Periods:
#  [(359, 19750), (22295, 322617)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (56 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 42
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (760 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 518
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Phasic periods in the lowpass signal: 10
# Periods:
#  [(140895, 143736)]
# Tonic periods in the lowpass signal: 1351
# Periods:
#  [(333, 140895), (143736, 451313)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (382 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 283
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (777 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 524
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 348
# Periods:
#  [(568, 118920)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (336 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 274
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 23
# Periods:
#  [(324, 7190)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (23 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 14
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 581
# Periods:
#  [(307, 196511)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (564 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 493
# Phasic periods in the lowpass signal: 9
# Periods:
#  [(308631, 311137)]
# Tonic periods in the lowpass signal: 1500
# Periods:
#  [(281, 308631), (311137, 502899)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (823 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 604
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (542 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 487
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 5
# Periods:
#  [(389, 2068)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (6 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 4
# Phasic periods in the lowpass signal: 8
# Periods:
#  [(22992, 25600)]
# Tonic periods in the lowpass signal: 211
# Periods:
#  [(349, 22992), (25600, 73191)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (69 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 55
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (145 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 130
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 112
# Periods:
#  [(253, 39944)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (115 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 96
# Phasic periods in the lowpass signal: 21
# Periods:
#  [(45899, 48598), (217171, 220579)]
# Tonic periods in the lowpass signal: 873
# Periods:
#  [(260, 45899), (48598, 217171), (220579, 298223)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (141 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 127
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (491 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 436
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (232 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 200
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (13 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 11
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 171
# Periods:
#  [(459, 57276)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (173 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 156
# Phasic periods in the lowpass signal: 43
# Periods:
#  [(34712, 36916), (49370, 52892), (76726, 81050), (182579, 184950)]
# Tonic periods in the lowpass signal: 503
# Periods:
#  [(406, 49370), (52892, 76726), (81050, 191149)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (141 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 124
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (72 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 68
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (311 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 288
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (14 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 12
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (15 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 13
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Phasic periods in the lowpass signal: 9
# Periods:
#  [(25997, 28718)]
# Tonic periods in the lowpass signal: 248
# Periods:
#  [(300, 25997), (28718, 87774)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (77 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 68
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (168 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 142
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Phasic periods in the lowpass signal: 51
# Periods:
#  [(65792, 67996), (80450, 83972), (107806, 112130), (208967, 216030)]
# Tonic periods in the lowpass signal: 596
# Periods:
#  [(408, 80450), (83972, 107806), (112130, 223648)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (236 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 218
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (72 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 68
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (316 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 291
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (14 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 12
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (15 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 13
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (24 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 22
# Phasic periods in the lowpass signal: 20
# Periods:
#  [(202737, 205024), (208297, 211171)]
# Tonic periods in the lowpass signal: 1151
# Periods:
#  [(178, 208297), (211171, 388529)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (634 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 583
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (523 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 487
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (12 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 10
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 58
# Periods:
#  [(209, 19794)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (59 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 55
# Phasic periods in the lowpass signal: 8
# Periods:
#  [(32910, 35171)]
# Tonic periods in the lowpass signal: 502
# Periods:
#  [(504, 159358)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (499 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 426
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 31
# Periods:
#  [(158, 9130)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (32 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 25
# Phasic periods in the lowpass signal: 9
# Periods:
#  [(166975, 169546)]
# Tonic periods in the lowpass signal: 567
# Periods:
#  [(300, 166975), (169546, 190325)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (504 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 442
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (62 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 53
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Phasic periods in the lowpass signal: 10
# Periods:
#  [(32196, 34957)]
# Tonic periods in the lowpass signal: 357
# Periods:
#  [(220, 32196), (34957, 118884)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (99 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 86
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (252 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 228
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 30
# Periods:
#  [(197, 9687)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (32 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 26
# Phasic periods in the lowpass signal: 11
# Periods:
#  [(184343, 187179)]
# Tonic periods in the lowpass signal: 844
# Periods:
#  [(267, 184343), (187179, 289117)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (551 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 509
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (287 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 252
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (12 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 10
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 348
# Periods:
#  [(224, 114476)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (349 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 293
# Phasic periods in the lowpass signal: 16
# Periods:
#  [(156082, 161255)]
# Tonic periods in the lowpass signal: 918
# Periods:
#  [(359, 298190)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (918 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 820
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (21 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 18
# Phasic periods in the lowpass signal: 11
# Periods:
#  [(15352, 18351)]
# Tonic periods in the lowpass signal: 306
# Periods:
#  [(388, 15352), (18351, 103124)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (47 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 42
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (261 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 217
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (12 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 10
# Phasic periods in the lowpass signal: 11
# Periods:
#  [(290943, 294112)]
# Tonic periods in the lowpass signal: 1271
# Periods:
#  [(297, 290943), (294112, 419470)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (881 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 800
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (369 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 347
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (12 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 10
# Phasic periods in the lowpass signal: 50
# Periods:
#  [(161123, 167398), (184346, 186958), (210590, 213526), (216949, 219574)]
# Tonic periods in the lowpass signal: 910
# Periods:
#  [(314, 163718), (167398, 184346), (186958, 210590), (213526, 216949), (219574, 313162)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (503 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 468
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (58 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 48
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (74 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 62
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (12 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 10
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (270 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 259
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (24 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 21
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 185
# Periods:
#  [(176, 59355)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (182 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 161
# Phasic periods in the lowpass signal: 27
# Periods:
#  [(49868, 52381), (134012, 136572), (279470, 282815)]
# Tonic periods in the lowpass signal: 1726
# Periods:
#  [(264, 49868), (52381, 134012), (136572, 279470), (282815, 593193)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (130 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 106
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (243 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 209
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (411 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 346
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (837 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 594
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (13 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 773
# Periods:
#  [(151, 259719)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (760 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 644
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 277
# Periods:
#  [(262, 90487)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (266 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 223
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 953
# Periods:
#  [(212, 306637)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (933 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 814
# Phasic periods in the lowpass signal: 11
# Periods:
#  [(118020, 121505)]
# Tonic periods in the lowpass signal: 542
# Periods:
#  [(378, 118020), (121505, 176702)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (285 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 205
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (181 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 139
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (12 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 10
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 3405
# Periods:
#  [(630, 1250508)]
# ...
# <class 'emd.cycles.Cycles'> (30 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 22
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (517 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 423
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Phasic periods in the lowpass signal: 31
# Periods:
#  [(194934, 197645), (205827, 209720), (227595, 229859)]
# Tonic periods in the lowpass signal: 796
# Periods:
#  [(288, 194934), (197645, 205827), (209720, 271252)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (596 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 539
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (26 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 24
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (179 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 158
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (14 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 12
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 207
# Periods:
#  [(280, 67617)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (207 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 175
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 70
# Periods:
#  [(419, 24267)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (74 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 66
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 927
# Periods:
#  [(144, 307016)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (850 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 688
# Phasic periods in the lowpass signal: 8
# Periods:
#  [(286586, 289039)]
# Tonic periods in the lowpass signal: 934
# Periods:
#  [(262, 320499)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (914 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 751
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Phasic periods in the lowpass signal: 8
# Periods:
#  [(151624, 153828)]
# Tonic periods in the lowpass signal: 664
# Periods:
#  [(455, 212660)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (624 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 518
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 1015
# Periods:
#  [(363, 341165)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (985 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 867
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 318
# Periods:
#  [(165, 111295)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (314 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 274
# Phasic periods in the lowpass signal: 8
# Periods:
#  [(173310, 175808)]
# Tonic periods in the lowpass signal: 703
# Periods:
#  [(451, 242496)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (700 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 594
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 631
# Periods:
#  [(515, 213877)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (633 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 536
# Phasic periods in the lowpass signal: 10
# Periods:
#  [(165466, 168872)]
# Tonic periods in the lowpass signal: 993
# Periods:
#  [(351, 165466), (168872, 323625)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (489 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 423
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (422 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 342
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Phasic periods in the lowpass signal: 24
# Periods:
#  [(61261, 63761), (238244, 242535)]
# Tonic periods in the lowpass signal: 918
# Periods:
#  [(151, 238244), (242535, 306464)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (709 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 598
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (173 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 139
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (17 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 15
# Phasic periods in the lowpass signal: 10
# Periods:
#  [(173160, 176097)]
# Tonic periods in the lowpass signal: 592
# Periods:
#  [(395, 173160), (176097, 195700)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (504 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 434
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (59 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 53
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 29
# Periods:
#  [(435, 10952)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (29 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 18
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 49
# Periods:
#  [(297, 17078)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (53 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 38
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 913
# Periods:
#  [(203, 304640)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (880 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 755
# Phasic periods in the lowpass signal: 13
# Periods:
#  [(17605, 21520)]
# Tonic periods in the lowpass signal: 585
# Periods:
#  [(671, 17605), (21520, 195640)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (46 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 40
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (451 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 373
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (14 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 12
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 1101
# Periods:
#  [(230, 356074)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (1067 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 864
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 659
# Periods:
#  [(343, 214522)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (656 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 545
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 135
# Periods:
#  [(330, 44629)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (133 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 99
# Phasic periods in the lowpass signal: 19
# Periods:
#  [(126413, 131793)]
# Tonic periods in the lowpass signal: 1561
# Periods:
#  [(261, 126413), (131793, 528771)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (326 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 246
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (1026 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 690
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (19 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 16
# Phasic periods in the lowpass signal: 9
# Periods:
#  [(300347, 304160)]
# Tonic periods in the lowpass signal: 1772
# Periods:
#  [(288, 300347), (304160, 589863)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (805 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 583
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (736 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 516
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (8 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 3
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 72
# Periods:
#  [(342, 22303)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (64 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 49
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 416
# Periods:
#  [(287, 137947)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (370 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 301
# Phasic periods in the lowpass signal: 8
# Periods:
#  [(95606, 97985)]
# Tonic periods in the lowpass signal: 841
# Periods:
#  [(157, 284817)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (839 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 759
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 48
# Periods:
#  [(358, 16456)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (48 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 43
# Phasic periods in the lowpass signal: 26
# Periods:
#  [(132918, 135267), (240904, 246409)]
# Tonic periods in the lowpass signal: 1578
# Periods:
#  [(450, 240904), (246409, 534985)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (716 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 637
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (813 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 628
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (19 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 17
# Phasic periods in the lowpass signal: 8
# Periods:
#  [(124103, 126793)]
# Tonic periods in the lowpass signal: 698
# Periods:
#  [(210, 124103), (126793, 233067)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (366 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 311
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (322 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 290
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 35
# Periods:
#  [(147, 12463)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (36 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 26
# Phasic periods in the lowpass signal: 47
# Periods:
#  [(145501, 147990), (152033, 154505), (161470, 165133), (365279, 369070), (373269, 375965)]
# Tonic periods in the lowpass signal: 1234
# Periods:
#  [(136, 161470), (165133, 365279), (369070, 373269), (375965, 424007)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (467 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 393
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (440 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 306
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (14 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 12
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (135 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 120
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (13 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 11
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Phasic periods in the lowpass signal: 9
# Periods:
#  [(94483, 97490)]
# Tonic periods in the lowpass signal: 693
# Periods:
#  [(174, 94483), (97490, 233285)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (274 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 222
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (357 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 295
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 12
# Periods:
#  [(267, 4308)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (13 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 11

# %%
path = "/home/miranjo/phasic_tonic/data/interim/"
for sample in remFolder:
    lfpREMs = sample["data"]
    metadata = sample["metadata"]
    
    save_name = metadata["RatID"]+"_"+metadata["StudyDay"]+"_"+metadata["condition"]+"_"+metadata["treatment"]+"_"+metadata["posstrial_number"]
    print(save_name)
    
    for i, lfpREM in enumerate(lfpREMs):
        theta = ThetaSignal(lfpREM, fs)
        
        if(theta.duration >= 1875/2500):
            theta.filter('lowpass', f_theta, n_seconds_filter)
            theta.segment_cycles()
        else:
            break

        save_name += "_" + str(i)
        
        for tonic in theta.get_tonic():
            df = emd_analysis(tonic, theta.sampling_rate)
            df.to_csv(path+save_name+"_tonic")

        if(theta.phasic == None):
            break
        else:
            for phasic in theta.get_phasic():
                df = emd_analysis(phasic, theta.sampling_rate)
                df.to_csv(path+save_name+"_phasic")
# Out:
# Rat5_SD5_OD_TreatmentPositive_posttrial4
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 663
# Periods:
#  [(293, 209426)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (621 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 518
# Rat3_SD6_OD_TreatmentPositive_posttrial5
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 1144
# Periods:
#  [(405, 386983)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (1111 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 950
# Rat5_SD6_HC_TreatmentPositive_posttrial4
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 748
# Periods:
#  [(139, 243773)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (716 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 571
# Rat4_SD9_HC_TreatmentNegative_posttrial3
# Phasic periods in the lowpass signal: 37
# Periods:
#  [(106769, 108988), (171557, 174665), (267131, 272657)]
# Tonic periods in the lowpass signal: 873
# Periods:
#  [(332, 171557), (174665, 267131), (269656, 269885), (272657, 305452)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (523 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 487
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (263 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 249
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (2 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 0
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (93 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 75
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (12 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 10
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (20 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 17
# Rat4_SD3_OR_TreatmentPositive_posttrial4
# Phasic periods in the lowpass signal: 16
# Periods:
#  [(144585, 146905), (347231, 349359)]
# Tonic periods in the lowpass signal: 1084
# Periods:
#  [(370, 365124)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (1096 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 1010
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Rat3_SD9_HC_TreatmentPositive_posttrial5
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 165
# Periods:
#  [(364, 50388)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (158 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 124
# Rat3_SD4_OD_TreatmentNegative_posttrial5
# Phasic periods in the lowpass signal: 8
# Periods:
#  [(696412, 698802)]
# Tonic periods in the lowpass signal: 8261
# Periods:
#  [(224, 2868921)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (6615 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 4048
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 6
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 175
# Periods:
#  [(354, 55150)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (168 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 135
# Rat4_SD3_OR_TreatmentPositive_posttrial5
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 203
# Periods:
#  [(310, 67217)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (205 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 180
# Rat3_SD7_HC_TreatmentPositive_posttrial5
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 605
# Periods:
#  [(321, 203060)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (592 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 519
# Rat4_SD5_HC_TreatmentNegative_posttrial2
# Phasic periods in the lowpass signal: 9
# Periods:
#  [(122352, 124860)]
# Tonic periods in the lowpass signal: 775
# Periods:
#  [(169, 122352), (124860, 254961)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (379 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 348
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (391 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 370
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Rat3_SD17_HC_TreatmentNegative_posttrial5
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 423
# Periods:
#  [(229, 143843)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (413 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 353
# Rat5_SD7_HC_TreatmentPositive_posttrial2
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 506
# Periods:
#  [(421, 164142)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (444 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 349
# Rat4_SD16_OR_TreatmentNegative_posttrial4
# Phasic periods in the lowpass signal: 21
# Periods:
#  [(105833, 108631), (150036, 153361)]
# Tonic periods in the lowpass signal: 562
# Periods:
#  [(513, 105833), (108631, 150036), (153361, 189191)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (322 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 298
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (134 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 121
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (103 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 95
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (12 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 10
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 171
# Periods:
#  [(506, 55979)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (171 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 165
# Rat4_SD8_HC_TreatmentPositive_posttrial4
# Phasic periods in the lowpass signal: 8
# Periods:
#  [(158801, 161206)]
# Tonic periods in the lowpass signal: 1103
# Periods:
#  [(198, 376946)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (1101 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 991
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 11
# Periods:
#  [(261, 3999)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (12 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Rat5_SD8_HC_TreatmentNegative_posttrial3
# Phasic periods in the lowpass signal: 10
# Periods:
#  [(145700, 148935)]
# Tonic periods in the lowpass signal: 1121
# Periods:
#  [(152, 145700), (148935, 384480)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (390 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 311
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (592 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 428
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Rat5_SD8_HC_TreatmentNegative_posttrial2
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 674
# Periods:
#  [(143, 218236)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (590 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 427
# Rat5_SD4_HC_TreatmentNegative_posttrial5
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 423
# Periods:
#  [(511, 138294)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (390 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 321
# Rat5_SD7_HC_TreatmentPositive_posttrial4
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 218
# Periods:
#  [(393, 74971)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (215 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 185
# Rat3_SD1_OR_TreatmentPositive_posttrial5
# Phasic periods in the lowpass signal: 8
# Periods:
#  [(140377, 143051)]
# Tonic periods in the lowpass signal: 1036
# Periods:
#  [(350, 140377), (143051, 357327)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (422 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 379
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (596 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 502
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 6
# Phasic periods in the lowpass signal: 8
# Periods:
#  [(21811, 24489)]
# Tonic periods in the lowpass signal: 634
# Periods:
#  [(255, 21811), (24489, 213309)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (64 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 57
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (572 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 505
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 266
# Periods:
#  [(555, 88472)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (259 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 228
# Rat4_SD2_HC_TreatmentNegative_posttrial5
# Phasic periods in the lowpass signal: 24
# Periods:
#  [(55297, 59346), (105307, 108165)]
# Tonic periods in the lowpass signal: 858
# Periods:
#  [(159, 55297), (59346, 105307), (108165, 295715)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (172 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 160
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (140 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 130
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (544 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 499
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (14 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 12
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (12 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 10
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 454
# Periods:
#  [(397, 151066)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (450 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 404
# Rat3_SD16_OR_TreatmentPositive_posttrial3
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 38
# Periods:
#  [(289, 12932)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (40 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 34
# Rat5_SD16_OR_TreatmentPositive_posttrial4
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 27
# Periods:
#  [(252, 8519)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (25 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 17
# Rat3_SD16_OR_TreatmentPositive_posttrial4
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 700
# Periods:
#  [(217, 241199)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (710 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 603
# Rat5_SD2_OR_TreatmentNegative_posttrial1
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 1141
# Periods:
#  [(329, 382560)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (1035 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 820
# Rat4_SD9_HC_TreatmentNegative_posttrial4
# Phasic periods in the lowpass signal: 30
# Periods:
#  [(49424, 52098), (162684, 165564), (175796, 178878)]
# Tonic periods in the lowpass signal: 803
# Periods:
#  [(187, 49424), (52098, 162684), (165564, 175796), (178878, 271397)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (150 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 138
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (342 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 320
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (31 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 26
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (278 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 260
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (12 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Phasic periods in the lowpass signal: 39
# Periods:
#  [(67886, 70036), (116075, 120239), (141147, 146297)]
# Tonic periods in the lowpass signal: 617
# Periods:
#  [(333, 116075), (120239, 141147), (146297, 215181)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (357 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 328
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (66 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 59
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (198 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 181
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (15 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 13
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (18 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 15
# Phasic periods in the lowpass signal: 27
# Periods:
#  [(64050, 66534), (182672, 184964), (307640, 310787)]
# Tonic periods in the lowpass signal: 974
# Periods:
#  [(315, 307640), (310787, 332703)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (924 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 850
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (65 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 57
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 42
# Periods:
#  [(192, 11619)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (43 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 39
# Rat4_SD17_HC_TreatmentNegative_posttrial3
# Phasic periods in the lowpass signal: 8
# Periods:
#  [(120885, 123091)]
# Tonic periods in the lowpass signal: 522
# Periods:
#  [(316, 166023)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (530 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 494
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Phasic periods in the lowpass signal: 8
# Periods:
#  [(32384, 34590)]
# Tonic periods in the lowpass signal: 443
# Periods:
#  [(381, 148211)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (446 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 412
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Rat5_SD3_OD_TreatmentNegative_posttrial3
# Phasic periods in the lowpass signal: 9
# Periods:
#  [(272343, 274901)]
# Tonic periods in the lowpass signal: 828
# Periods:
#  [(380, 272343), (274901, 280622)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (761 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 625
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (19 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 14
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Rat5_SD14_OR_TreatmentNegative_posttrial3
# Phasic periods in the lowpass signal: 9
# Periods:
#  [(119437, 121842)]
# Tonic periods in the lowpass signal: 618
# Periods:
#  [(415, 204454)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (584 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 482
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 39
# Periods:
#  [(484, 13677)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (36 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 18
# Rat4_SD6_OD_TreatmentNegative_posttrial5
# Phasic periods in the lowpass signal: 75
# Periods:
#  [(65355, 68258), (83497, 86796), (340195, 342628), (345829, 349181), (375479, 378240), (441042, 443361), (486257, 489012), (512436, 514775)]
# Tonic periods in the lowpass signal: 1511
# Periods:
#  [(365, 65355), (68258, 83497), (86796, 345829), (349181, 375479), (378240, 486257), (489012, 525709)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (209 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 191
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (43 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 35
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (753 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 615
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (86 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 79
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (315 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 295
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (107 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 96
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (12 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 10
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (13 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 11
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Phasic periods in the lowpass signal: 17
# Periods:
#  [(96178, 98966), (158124, 160561)]
# Tonic periods in the lowpass signal: 920
# Periods:
#  [(170, 96178), (98966, 303366)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (306 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 268
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (618 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 551
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Phasic periods in the lowpass signal: 9
# Periods:
#  [(39615, 42225)]
# Tonic periods in the lowpass signal: 190
# Periods:
#  [(549, 39615), (42225, 61124)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (125 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 112
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (66 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 57
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Phasic periods in the lowpass signal: 38
# Periods:
#  [(209062, 211973), (233234, 237206), (247044, 249359), (253455, 255612)]
# Tonic periods in the lowpass signal: 803
# Periods:
#  [(241, 209062), (211973, 233234), (237206, 278467)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (631 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 586
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (61 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 57
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (125 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 100
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (14 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 12
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Phasic periods in the lowpass signal: 10
# Periods:
#  [(15863, 19017)]
# Tonic periods in the lowpass signal: 116
# Periods:
#  [(153, 15863), (19017, 41302)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (51 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 40
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (68 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 62
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Phasic periods in the lowpass signal: 8
# Periods:
#  [(84388, 86645)]
# Tonic periods in the lowpass signal: 346
# Periods:
#  [(154, 119788)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (355 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 324
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Phasic periods in the lowpass signal: 28
# Periods:
#  [(214138, 216435), (227584, 230664), (298085, 300812)]
# Tonic periods in the lowpass signal: 963
# Periods:
#  [(175, 227584), (230664, 298085), (300812, 325353)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (692 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 659
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (209 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 197
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (74 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 65
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (12 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 10
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 161
# Periods:
#  [(148, 54010)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (164 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 145
# Rat3_SD6_OD_TreatmentPositive_posttrial2
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 614
# Periods:
#  [(367, 206779)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (589 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 461
# Rat4_SD7_HC_TreatmentPositive_posttrial4
# Phasic periods in the lowpass signal: 60
# Periods:
#  [(133768, 136267), (188415, 197698), (212594, 215378), (243005, 245641), (274119, 277049)]
# Tonic periods in the lowpass signal: 868
# Periods:
#  [(329, 188415), (193176, 212594), (215378, 243005), (245641, 274119), (277049, 311332)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (561 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 517
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (62 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 57
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (80 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 73
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (78 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 69
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (101 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 92
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (32 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 27
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Rat5_SD8_HC_TreatmentNegative_posttrial5
# Phasic periods in the lowpass signal: 9
# Periods:
#  [(19750, 22295)]
# Tonic periods in the lowpass signal: 958
# Periods:
#  [(359, 19750), (22295, 322617)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (56 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 42
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (760 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 518
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Phasic periods in the lowpass signal: 10
# Periods:
#  [(140895, 143736)]
# Tonic periods in the lowpass signal: 1351
# Periods:
#  [(333, 140895), (143736, 451313)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (382 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 283
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (777 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 524
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 348
# Periods:
#  [(568, 118920)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (336 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 274
# Rat4_SD2_HC_TreatmentNegative_posttrial2
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 23
# Periods:
#  [(324, 7190)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (23 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 14
# Rat3_SD1_OR_TreatmentPositive_posttrial4
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 581
# Periods:
#  [(307, 196511)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (564 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 493
# Rat5_SD2_OR_TreatmentNegative_posttrial4
# Phasic periods in the lowpass signal: 9
# Periods:
#  [(308631, 311137)]
# Tonic periods in the lowpass signal: 1500
# Periods:
#  [(281, 308631), (311137, 502899)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (823 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 604
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (542 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 487
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 5
# Periods:
#  [(389, 2068)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (6 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 4
# Rat3_SD3_OR_TreatmentNegative_posttrial3
# Phasic periods in the lowpass signal: 8
# Periods:
#  [(22992, 25600)]
# Tonic periods in the lowpass signal: 211
# Periods:
#  [(349, 22992), (25600, 73191)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (69 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 55
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (145 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 130
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 112
# Periods:
#  [(253, 39944)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (115 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 96
# Rat4_SD4_OD_TreatmentPositive_posttrial5
# Phasic periods in the lowpass signal: 21
# Periods:
#  [(45899, 48598), (217171, 220579)]
# Tonic periods in the lowpass signal: 873
# Periods:
#  [(260, 45899), (48598, 217171), (220579, 298223)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (141 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 127
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (491 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 436
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (232 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 200
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (13 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 11
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 171
# Periods:
#  [(459, 57276)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (173 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 156
# Rat4_SD1_OR_TreatmentNegative_posttrial5
# Phasic periods in the lowpass signal: 43
# Periods:
#  [(34712, 36916), (49370, 52892), (76726, 81050), (182579, 184950)]
# Tonic periods in the lowpass signal: 503
# Periods:
#  [(406, 49370), (52892, 76726), (81050, 191149)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (141 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 124
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (72 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 68
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (311 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 288
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (14 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 12
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (15 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 13
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Phasic periods in the lowpass signal: 9
# Periods:
#  [(25997, 28718)]
# Tonic periods in the lowpass signal: 248
# Periods:
#  [(300, 25997), (28718, 87774)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (77 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 68
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (168 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 142
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Phasic periods in the lowpass signal: 51
# Periods:
#  [(65792, 67996), (80450, 83972), (107806, 112130), (208967, 216030)]
# Tonic periods in the lowpass signal: 596
# Periods:
#  [(408, 80450), (83972, 107806), (112130, 223648)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (236 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 218
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (72 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 68
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (316 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 291
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (14 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 12
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (15 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 13
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (24 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 22
# Phasic periods in the lowpass signal: 20
# Periods:
#  [(202737, 205024), (208297, 211171)]
# Tonic periods in the lowpass signal: 1151
# Periods:
#  [(178, 208297), (211171, 388529)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (634 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 583
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (523 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 487
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (12 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 10
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 58
# Periods:
#  [(209, 19794)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (59 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 55
# Rat3_SD5_HC_TreatmentNegative_posttrial5
# Phasic periods in the lowpass signal: 8
# Periods:
#  [(32910, 35171)]
# Tonic periods in the lowpass signal: 502
# Periods:
#  [(504, 159358)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (499 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 426
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 31
# Periods:
#  [(158, 9130)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (32 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 25
# Rat3_SD4_OD_TreatmentNegative_posttrial4
# Phasic periods in the lowpass signal: 9
# Periods:
#  [(166975, 169546)]
# Tonic periods in the lowpass signal: 567
# Periods:
#  [(300, 166975), (169546, 190325)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (504 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 442
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (62 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 53
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Phasic periods in the lowpass signal: 10
# Periods:
#  [(32196, 34957)]
# Tonic periods in the lowpass signal: 357
# Periods:
#  [(220, 32196), (34957, 118884)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (99 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 86
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (252 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 228
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 30
# Periods:
#  [(197, 9687)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (32 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 26
# Rat4_SD6_OD_TreatmentNegative_posttrial2
# Phasic periods in the lowpass signal: 11
# Periods:
#  [(184343, 187179)]
# Tonic periods in the lowpass signal: 844
# Periods:
#  [(267, 184343), (187179, 289117)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (551 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 509
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (287 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 252
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (12 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 10
# Rat3_SD5_HC_TreatmentNegative_posttrial1
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 348
# Periods:
#  [(224, 114476)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (349 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 293
# Rat4_SD17_HC_TreatmentNegative_posttrial5
# Phasic periods in the lowpass signal: 16
# Periods:
#  [(156082, 161255)]
# Tonic periods in the lowpass signal: 918
# Periods:
#  [(359, 298190)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (918 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 820
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (21 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 18
# Phasic periods in the lowpass signal: 11
# Periods:
#  [(15352, 18351)]
# Tonic periods in the lowpass signal: 306
# Periods:
#  [(388, 15352), (18351, 103124)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (47 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 42
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (261 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 217
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (12 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 10
# Phasic periods in the lowpass signal: 11
# Periods:
#  [(290943, 294112)]
# Tonic periods in the lowpass signal: 1271
# Periods:
#  [(297, 290943), (294112, 419470)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (881 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 800
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (369 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 347
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (12 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 10
# Phasic periods in the lowpass signal: 50
# Periods:
#  [(161123, 167398), (184346, 186958), (210590, 213526), (216949, 219574)]
# Tonic periods in the lowpass signal: 910
# Periods:
#  [(314, 163718), (167398, 184346), (186958, 210590), (213526, 216949), (219574, 313162)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (503 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 468
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (58 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 48
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (74 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 62
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (12 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 10
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (270 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 259
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (24 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 21
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 185
# Periods:
#  [(176, 59355)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (182 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 161
# Rat3_SD7_HC_TreatmentPositive_posttrial3
# Phasic periods in the lowpass signal: 27
# Periods:
#  [(49868, 52381), (134012, 136572), (279470, 282815)]
# Tonic periods in the lowpass signal: 1726
# Periods:
#  [(264, 49868), (52381, 134012), (136572, 279470), (282815, 593193)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (130 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 106
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (243 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 209
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (411 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 346
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (837 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 594
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# ...
# <class 'emd.cycles.Cycles'> (596 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 539
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (26 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 24
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (179 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 158
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (14 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 12
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Rat3_SD16_OR_TreatmentPositive_posttrial5
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 207
# Periods:
#  [(280, 67617)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (207 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 175
# Rat4_SD6_OD_TreatmentNegative_posttrial3
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 70
# Periods:
#  [(419, 24267)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (74 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 66
# Rat5_SD14_OR_TreatmentNegative_posttrial4
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 927
# Periods:
#  [(144, 307016)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (850 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 688
# Rat3_SD17_HC_TreatmentNegative_posttrial3
# Phasic periods in the lowpass signal: 8
# Periods:
#  [(286586, 289039)]
# Tonic periods in the lowpass signal: 934
# Periods:
#  [(262, 320499)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (914 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 751
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Rat5_SD14_OR_TreatmentNegative_posttrial2
# Phasic periods in the lowpass signal: 8
# Periods:
#  [(151624, 153828)]
# Tonic periods in the lowpass signal: 664
# Periods:
#  [(455, 212660)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (624 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 518
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Rat3_SD8_HC_TreatmentNegative_posttrial4
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 1015
# Periods:
#  [(363, 341165)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (985 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 867
# Rat3_SD4_OD_TreatmentNegative_posttrial3
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 318
# Periods:
#  [(165, 111295)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (314 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 274
# Rat3_SD17_HC_TreatmentNegative_posttrial4
# Phasic periods in the lowpass signal: 8
# Periods:
#  [(173310, 175808)]
# Tonic periods in the lowpass signal: 703
# Periods:
#  [(451, 242496)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (700 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 594
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 631
# Periods:
#  [(515, 213877)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (633 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 536
# Rat5_SD16_OR_TreatmentPositive_posttrial5
# Phasic periods in the lowpass signal: 10
# Periods:
#  [(165466, 168872)]
# Tonic periods in the lowpass signal: 993
# Periods:
#  [(351, 165466), (168872, 323625)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (489 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 423
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (422 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 342
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Phasic periods in the lowpass signal: 24
# Periods:
#  [(61261, 63761), (238244, 242535)]
# Tonic periods in the lowpass signal: 918
# Periods:
#  [(151, 238244), (242535, 306464)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (709 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 598
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (173 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 139
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (17 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 15
# Phasic periods in the lowpass signal: 10
# Periods:
#  [(173160, 176097)]
# Tonic periods in the lowpass signal: 592
# Periods:
#  [(395, 173160), (176097, 195700)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (504 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 434
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (59 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 53
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 29
# Periods:
#  [(435, 10952)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (29 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 18
# Rat4_SD3_OR_TreatmentPositive_posttrial3
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 49
# Periods:
#  [(297, 17078)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (53 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 38
# Rat5_SD1_OR_TreatmentPositive_posttrial4
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 913
# Periods:
#  [(203, 304640)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (880 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 755
# Rat5_SD3_OD_TreatmentNegative_posttrial5
# Phasic periods in the lowpass signal: 13
# Periods:
#  [(17605, 21520)]
# Tonic periods in the lowpass signal: 585
# Periods:
#  [(671, 17605), (21520, 195640)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (46 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 40
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (451 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 373
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (14 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 12
# Rat3_SD9_HC_TreatmentPositive_posttrial4
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 1101
# Periods:
#  [(230, 356074)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (1067 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 864
# Rat3_SD9_HC_TreatmentPositive_posttrial3
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 659
# Periods:
#  [(343, 214522)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (656 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 545
# Rat4_SD2_HC_TreatmentNegative_posttrial3
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 135
# Periods:
#  [(330, 44629)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (133 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 99
# Rat5_SD8_HC_TreatmentNegative_posttrial4
# Phasic periods in the lowpass signal: 19
# Periods:
#  [(126413, 131793)]
# Tonic periods in the lowpass signal: 1561
# Periods:
#  [(261, 126413), (131793, 528771)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (326 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 246
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (1026 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 690
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (19 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 16
# Phasic periods in the lowpass signal: 9
# Periods:
#  [(300347, 304160)]
# Tonic periods in the lowpass signal: 1772
# Periods:
#  [(288, 300347), (304160, 589863)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (805 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 583
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (736 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 516
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (8 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 3
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 72
# Periods:
#  [(342, 22303)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (64 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 49
# Rat5_SD4_HC_TreatmentNegative_posttrial2
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 416
# Periods:
#  [(287, 137947)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (370 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 301
# Rat4_SD16_OR_TreatmentNegative_posttrial5
# Phasic periods in the lowpass signal: 8
# Periods:
#  [(95606, 97985)]
# Tonic periods in the lowpass signal: 841
# Periods:
#  [(157, 284817)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (839 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 759
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 48
# Periods:
#  [(358, 16456)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (48 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 43
# Rat3_SD8_HC_TreatmentNegative_posttrial5
# Phasic periods in the lowpass signal: 26
# Periods:
#  [(132918, 135267), (240904, 246409)]
# Tonic periods in the lowpass signal: 1578
# Periods:
#  [(450, 240904), (246409, 534985)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (716 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 637
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (813 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 628
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (19 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 17
# Phasic periods in the lowpass signal: 8
# Periods:
#  [(124103, 126793)]
# Tonic periods in the lowpass signal: 698
# Periods:
#  [(210, 124103), (126793, 233067)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (366 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 311
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (322 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 290
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 35
# Periods:
#  [(147, 12463)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (36 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 26
# Rat5_SD17_HC_TreatmentPositive_posttrial5
# Phasic periods in the lowpass signal: 47
# Periods:
#  [(145501, 147990), (152033, 154505), (161470, 165133), (365279, 369070), (373269, 375965)]
# Tonic periods in the lowpass signal: 1234
# Periods:
#  [(136, 161470), (165133, 365279), (369070, 373269), (375965, 424007)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (467 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 393
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (440 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 306
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (14 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 12
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (135 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 120
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (13 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 11
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Phasic periods in the lowpass signal: 9
# Periods:
#  [(94483, 97490)]
# Tonic periods in the lowpass signal: 693
# Periods:
#  [(174, 94483), (97490, 233285)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (274 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 222
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (357 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 295
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Phasic periods in the lowpass signal: 0
# No phasic periods detected
# Tonic periods in the lowpass signal: 12
# Periods:
#  [(267, 4308)]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (13 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 11

# %%
len(remFolder)
# Out:
# 102

# %%
#{'RatID': 'Rat5', 'StudyDay': 'SD8', 'condition': 'HC', 'condition_full': 'HomeCage', 'treatment': 'TreatmentNegative', 'posstrial_number': 'posttrial3'}

# %%
import matplotlib.pyplot as plt

def plot_bar(feature, bins, ax=None, density=False, **kwargs):

    # Default keyword args
    figsize = kwargs.pop('figsize', (5, 5))
    xlabel = kwargs.pop('xlabel', None)
    xlim = kwargs.pop('xlim', None)
    ylim = kwargs.pop('ylim', None)
    fontsize = kwargs.pop('fontsize', 15)
    alpha = kwargs.pop('alpha', .7)

    if ax is None:
        fig, ax = plt.subplots(figsize=figsize)

    # Axis style
    ax.set_xlabel(xlabel, size=fontsize)

    if density:
        ax.set_ylabel('Cycles density', size=fontsize)
    else:
        ax.set_ylabel('Number of cycles', size=fontsize)

    if xlim is not None:
        ax.set_xlim(xlim)

    if ylim is not None:
        ax.set_xlim(ylim)
        
    ax.bar(bins[:-1], feature, alpha=alpha, **kwargs)

# %%
data=oc_hist_tonic[1]
plt.bar(bins[:-1], data, width=0.01)
plt.title("OC Tonic: Peak to Trough ratio")
# Out:
# Text(0.5, 1.0, 'OC Tonic: Peak to Trough ratio')

# %%
data=hc_hist_tonic[1]
plt.bar(bins[:-1], data, width=0.01)
plt.title("HC Tonic: Peak to Trough ratio")
# Out:
# Text(0.5, 1.0, 'HC Tonic: Peak to Trough ratio')

# %%
fig, axes = plt.subplots(figsize=(15, 15), nrows=2, ncols=2)

# OC Tonic
dist1 = oc_hist_tonic[0]
dist2 = hc_hist_tonic[0]

plot_bar(dist1, bins, ax=axes[0][0], xlabel="Ascending to Descending ratio", color='r')
plot_bar(dist2, bins, ax=axes[0][0], xlabel="Ascending to Descending ratio", color='k')
axes[0][0].legend(['Phasic', 'Tonic'], fontsize=15)
