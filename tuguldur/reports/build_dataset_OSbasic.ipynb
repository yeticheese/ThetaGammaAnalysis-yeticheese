# %%
import os
import re
from pathlib import Path

import numpy as np
from scipy.io import loadmat

DATASET_DIR = "/home/nero/datasets/OSbasic/"
OUTPUT_DIR  = "/home/nero/datasets/processed/"

def rem_extract(lfp, sleep_trans):
    """
    Extract REM sleep data from a LFP using sleep transition times.

    Parameters:
        lfp (numpy.ndarray): A NumPy array.
        sleep_trans (numpy.ndarray): A NumPy array containing pairs of sleep transition times.

    Returns:
        list of numpy.ndarray: A list of NumPy arrays, each representing a segment of REM sleep data.
    """
    rems = []

    for rem in sleep_trans:
        t1 = int(rem[0])
        t2 = int(rem[1])
        rems.append(lfp[t1:t2])

    return rems

def get_rem_states(states, sample_rate):
    """
    Extract consecutive REM (Rapid Eye Movement) sleep states and their start
    and end times from an array of sleep states.

    Parameters:
    - states (numpy.ndarray): One-dimensional array of sleep states.
    - sample_rate (int): The sample rate of the data.

    Returns:
    numpy.ndarray: An array containing start and end times of consecutive REM
    sleep states. Each row represents a pair of start and end times.

    Note:
    - Sleep states are represented numerically. In this function, REM sleep
      states are identified by the value 5 in the 'states' array.

    Example:
    ```python
    import numpy as np

    # Example usage:
    sleep_states = np.array([1, 2, 5, 5, 5, 3, 2, 5, 5, 4, 1])
    sample_rate = 2500  # Example sample rate in Hz
    rem_states_times = get_rem_states(sleep_states, sample_rate)
    print(rem_states_times)
    ```
    """
    try:
        # Ensure the sleep states array is one-dimensional.
        states = np.squeeze(states)
        # Find the indices where the sleep state is equal to 5, indicating REM sleep.
        rem_state_indices = np.where(states == 5)[0]
        
        # Check if there are no REM states. If so, return an empty array.
        if len(rem_state_indices) == 0:
            return np.array([])
        # Calculate the changes between consecutive REM state indices.
        rem_state_changes = np.diff(rem_state_indices)
        # Find the indices where consecutive REM states are not adjacent.
        split_indices = np.where(rem_state_changes != 1)[0] + 1
        # Add indices to split consecutive REM states, including the start and end indices.
        split_indices = np.concatenate(([0], split_indices, [len(rem_state_indices)]))
        # Create an empty array to store start and end times of consecutive REM states.
        consecutive_rem_states = np.empty((len(split_indices) - 1, 2))
        # Iterate through the split indices to extract start and end times.
        for i, (start, end) in enumerate(zip(split_indices, split_indices[1:])):
            start = rem_state_indices[start] * int(sample_rate)
            end = rem_state_indices[end - 1] * int(sample_rate)
            consecutive_rem_states[i] = np.array([start, end])
        # Convert the array to a numpy array.
        ##consecutive_rem_states = np.array(consecutive_rem_states)
        # Create a mask to filter out consecutive REM states with negative duration.
        null_states_mask = np.squeeze(np.diff(consecutive_rem_states) > 0)
        consecutive_rem_states = consecutive_rem_states[null_states_mask]
        # Return the array containing start and end times of consecutive REM states.
        return consecutive_rem_states
    # Handle the case where an IndexError occurs, typically due to an empty array.
    except IndexError as e:
        print(f"An IndexError occurred in get_rem_states: {e}")
        return np.array([])  # or any default value you want

def create_name(fname):
    metadata = fname.split("_")
    title = metadata[1] + "_" + metadata[2] + "_" + metadata[3]
    #RatID,StudyDay,condition,conditionfull, treatment, treatmentfull, posstrial number
    return title

# %%
#pattern1 = r"[\w-]+post[\w-]+trial[\w-]+"
pattern1 = r".*post_trial.*"
mapped = {}

for root, dirs, fils in os.walk(DATASET_DIR):
    for dir in dirs:
        dir = (os.path.join(root, dir))
        # Check if the directory is a post trial directory
        if re.match(pattern1, dir, flags=re.IGNORECASE):
            dir = Path(dir)
            print("MATCH: ", dir)
            HPC_file = next(dir.glob("*HPC*"))
            states = next(dir.glob('*states*'))
            mapped[states] = HPC_file
        else:
            print("No match:", dir)

len(mapped)
# Out:
# No match: /home/nero/datasets/OSbasic/1
# No match: /home/nero/datasets/OSbasic/9
# No match: /home/nero/datasets/OSbasic/13
# No match: /home/nero/datasets/OSbasic/6
# No match: /home/nero/datasets/OSbasic/3
# No match: /home/nero/datasets/OSbasic/4
# No match: /home/nero/datasets/OSbasic/11
# No match: /home/nero/datasets/OSbasic/1/Rat-OS-Ephys_Rat1_SD1_OD_21-09-2017
# No match: /home/nero/datasets/OSbasic/1/Rat-OS-Ephys_Rat1_SD2_OR_25-09-2017
# No match: /home/nero/datasets/OSbasic/1/Rat-OS-Ephys_Rat1_SD4_CON_28-09-2017
# No match: /home/nero/datasets/OSbasic/1/Rat-OS-Ephys_Rat1_SD3_HC_27-09-2017
# No match: /home/nero/datasets/OSbasic/1/Rat-OS-Ephys_Rat1_SD5_OR-N_03-10-2017
# MATCH:  /home/nero/datasets/OSbasic/1/Rat-OS-Ephys_Rat1_SD1_OD_21-09-2017/post_trial5_2017-09-21_14-31-51
# No match: /home/nero/datasets/OSbasic/1/Rat-OS-Ephys_Rat1_SD1_OD_21-09-2017/presleep_2017-09-21_10-12-40
# MATCH:  /home/nero/datasets/OSbasic/1/Rat-OS-Ephys_Rat1_SD1_OD_21-09-2017/post_trial1_2017-09-21_11-06-43
# MATCH:  /home/nero/datasets/OSbasic/1/Rat-OS-Ephys_Rat1_SD1_OD_21-09-2017/post_trial4_2017-09-21_13-40-22
# MATCH:  /home/nero/datasets/OSbasic/1/Rat-OS-Ephys_Rat1_SD1_OD_21-09-2017/post_trial2_2017-09-21_11-57-34
# MATCH:  /home/nero/datasets/OSbasic/1/Rat-OS-Ephys_Rat1_SD1_OD_21-09-2017/post_trial3_2017-09-21_12-48-10
# MATCH:  /home/nero/datasets/OSbasic/1/Rat-OS-Ephys_Rat1_SD2_OR_25-09-2017/post_trial4_2017-09-25_14-01-00
# MATCH:  /home/nero/datasets/OSbasic/1/Rat-OS-Ephys_Rat1_SD2_OR_25-09-2017/post_trial2_2017-09-25_12-17-49
# No match: /home/nero/datasets/OSbasic/1/Rat-OS-Ephys_Rat1_SD2_OR_25-09-2017/presleep_2017-09-25_10-30-34
# MATCH:  /home/nero/datasets/OSbasic/1/Rat-OS-Ephys_Rat1_SD2_OR_25-09-2017/post_trial1_2017-09-25_11-26-43
# MATCH:  /home/nero/datasets/OSbasic/1/Rat-OS-Ephys_Rat1_SD2_OR_25-09-2017/post_trial5_2017-09-25_14-52-04
# MATCH:  /home/nero/datasets/OSbasic/1/Rat-OS-Ephys_Rat1_SD2_OR_25-09-2017/post_trial3_2017-09-25_13-08-52
# MATCH:  /home/nero/datasets/OSbasic/1/Rat-OS-Ephys_Rat1_SD4_CON_28-09-2017/post_trial2_2017-09-28_12-21-41
# MATCH:  /home/nero/datasets/OSbasic/1/Rat-OS-Ephys_Rat1_SD4_CON_28-09-2017/post_trial5_2017-09-28_14-55-18
# MATCH:  /home/nero/datasets/OSbasic/1/Rat-OS-Ephys_Rat1_SD4_CON_28-09-2017/post_trial4_2017-09-28_14-03-38
# MATCH:  /home/nero/datasets/OSbasic/1/Rat-OS-Ephys_Rat1_SD4_CON_28-09-2017/post_trial3_2017-09-28_13-12-53
# MATCH:  /home/nero/datasets/OSbasic/1/Rat-OS-Ephys_Rat1_SD4_CON_28-09-2017/post_trial1_2017-09-28_11-30-59
# No match: /home/nero/datasets/OSbasic/1/Rat-OS-Ephys_Rat1_SD4_CON_28-09-2017/presleep_2017-09-28_10-38-28
# MATCH:  /home/nero/datasets/OSbasic/1/Rat-OS-Ephys_Rat1_SD3_HC_27-09-2017/post_trial5_2017-09-27_14-18-24
# MATCH:  /home/nero/datasets/OSbasic/1/Rat-OS-Ephys_Rat1_SD3_HC_27-09-2017/post_trial1_2017-09-27_10-56-20
# MATCH:  /home/nero/datasets/OSbasic/1/Rat-OS-Ephys_Rat1_SD3_HC_27-09-2017/post_trial4_2017-09-27_13-27-32
# No match: /home/nero/datasets/OSbasic/1/Rat-OS-Ephys_Rat1_SD3_HC_27-09-2017/presleep_2017-09-27_10-02-30
# MATCH:  /home/nero/datasets/OSbasic/1/Rat-OS-Ephys_Rat1_SD3_HC_27-09-2017/post_trial3_2017-09-27_12-37-12
# MATCH:  /home/nero/datasets/OSbasic/1/Rat-OS-Ephys_Rat1_SD3_HC_27-09-2017/post_trial2_2017-09-27_11-46-56
# MATCH:  /home/nero/datasets/OSbasic/1/Rat-OS-Ephys_Rat1_SD5_OR-N_03-10-2017/post_trial5_2017-10-03_15-12-56
# MATCH:  /home/nero/datasets/OSbasic/1/Rat-OS-Ephys_Rat1_S
home/nero/datasets/OSbasic/11/Rat-OS-Ephys_Rat11_SD4_OR_03-11-2018/2018-11-05_10-49-36_Post_Trial1
# No match: /home/nero/datasets/OSbasic/11/Rat-OS-Ephys_Rat11_SD4_OR_03-11-2018/2018-11-05_09-58-51_Pre-sleep
# MATCH:  /home/nero/datasets/OSbasic/11/Rat-OS-Ephys_Rat11_SD4_OR_03-11-2018/2018-11-05_13-24-55_Post_Trial4
# MATCH:  /home/nero/datasets/OSbasic/11/Rat-OS-Ephys_Rat11_SD4_OR_03-11-2018/2018-11-05_11-40-05_Post_Trial2
# MATCH:  /home/nero/datasets/OSbasic/11/Rat-OS-Ephys_Rat11_SD4_OR_03-11-2018/2018-11-05_14-15-28_Post_Trial5
# MATCH:  /home/nero/datasets/OSbasic/11/Rat-OS-Ephys_Rat11_SD4_OR_03-11-2018/2018-11-05_12-34-14_Post_Trial3
# 210

# %%
for state in mapped.keys():
    hpc = mapped[state]
    lfp = loadmat(hpc)['HPC']
    lfp = np.squeeze(lfp)
    sleep = loadmat(state)
    states = np.squeeze(sleep['states'])

    if(np.any(states == 5)):
        rem_transitions = get_rem_states(states, 2500).astype(int)
        if rem_transitions.ndim == 3:
            rem_transitions = np.squeeze(rem_transitions, 0)

        lfpREM = rem_extract(lfp, rem_transitions)

        # Extract metadata

        title = create_name(str(hpc.parent.parent.name))
        pattern = r"post_trial(\d+)"
        match = re.search(pattern, str(hpc), re.IGNORECASE)
        title += "_4_" + "posttrial" + match.group(1)

        fname = OUTPUT_DIR + title
        print(fname)
        
        np.savez(fname, *lfpREM)
# Out:
# /home/nero/datasets/processed/Rat1_SD1_OD_4_posttrial5
# /home/nero/datasets/processed/Rat1_SD1_OD_4_posttrial1
# /home/nero/datasets/processed/Rat1_SD1_OD_4_posttrial4
# /home/nero/datasets/processed/Rat1_SD1_OD_4_posttrial2
# /home/nero/datasets/processed/Rat1_SD1_OD_4_posttrial3
# /home/nero/datasets/processed/Rat1_SD2_OR_4_posttrial4
# /home/nero/datasets/processed/Rat1_SD2_OR_4_posttrial2
# /home/nero/datasets/processed/Rat1_SD2_OR_4_posttrial1
# /home/nero/datasets/processed/Rat1_SD2_OR_4_posttrial5
# /home/nero/datasets/processed/Rat1_SD2_OR_4_posttrial3
# /home/nero/datasets/processed/Rat1_SD4_CON_4_posttrial2
# /home/nero/datasets/processed/Rat1_SD4_CON_4_posttrial5
# /home/nero/datasets/processed/Rat1_SD4_CON_4_posttrial4
# /home/nero/datasets/processed/Rat1_SD4_CON_4_posttrial3
# /home/nero/datasets/processed/Rat1_SD4_CON_4_posttrial1
# /home/nero/datasets/processed/Rat1_SD3_HC_4_posttrial5
# /home/nero/datasets/processed/Rat1_SD3_HC_4_posttrial1
# /home/nero/datasets/processed/Rat1_SD3_HC_4_posttrial4
# /home/nero/datasets/processed/Rat1_SD3_HC_4_posttrial3
# /home/nero/datasets/processed/Rat1_SD3_HC_4_posttrial2
# /home/nero/datasets/processed/Rat1_SD5_OR-N_4_posttrial5
# /home/nero/datasets/processed/Rat1_SD5_OR-N_4_posttrial4
# /home/nero/datasets/processed/Rat9_SD3_HC_4_posttrial2
# /home/nero/datasets/processed/Rat9_SD3_HC_4_posttrial3
# /home/nero/datasets/processed/Rat9_SD3_HC_4_posttrial5
# /home/nero/datasets/processed/Rat9_SD3_HC_4_posttrial1
# /home/nero/datasets/processed/Rat9_SD3_HC_4_posttrial4
# /home/nero/datasets/processed/Rat9_SD4_OD_4_posttrial5
# /home/nero/datasets/processed/Rat9_SD4_OD_4_posttrial4
# /home/nero/datasets/processed/Rat9_SD4_OD_4_posttrial1
# /home/nero/datasets/processed/Rat9_SD4_OD_4_posttrial2
# /home/nero/datasets/processed/Rat9_SD4_OD_4_posttrial3
# /home/nero/datasets/processed/Rat9_SD10_OR_4_posttrial2
# /home/nero/datasets/processed/Rat9_SD10_OR_4_posttrial4
# /home/nero/datasets/processed/Rat9_SD10_OR_4_posttrial1
# /home/nero/datasets/processed/Rat9_SD10_OR_4_posttrial5
# /home/nero/datasets/processed/Rat9_SD10_OR_4_posttrial3
# /home/nero/datasets/processed/Rat9_SD2_CON_4_posttrial1
# /home/nero/datasets/processed/Rat9_SD2_CON_4_posttrial2
# /home/nero/datasets/processed/Rat9_SD2_CON_4_posttrial5
# /home/nero/datasets/processed/Rat9_SD2_CON_4_posttrial3
# /home/nero/datasets/processed/Rat9_SD2_CON_4_posttrial4
# /home/nero/datasets/processed/Rat9_SD16_OR-N_4_posttrial4
# /home/nero/datasets/processed/Rat9_SD16_OR-N_4_posttrial3
# /home/nero/datasets/processed/Rat9_SD16_OR-N_4_posttrial1
# /home/nero/datasets/processed/Rat9_SD16_OR-N_4_posttrial5
# /home/nero/datasets/processed/Rat13_SD4_OD_4_posttrial5
# /home/nero/datasets/processed/Rat13_SD3_OR_4_posttrial3
# /home/nero/datasets/processed/Rat13_SD3_OR_4_posttrial5
# /home/nero/datasets/processed/Rat13_SD3_OR_4_posttrial4
# /home/nero/datasets/processed/Rat13_SD3_OR_4_posttrial2
# /home/nero/datasets/processed/Rat13_SD2_HC_4_posttrial4
# /home/nero/datasets/processed/Rat13_SD2_HC_4_posttrial5
# /home/nero/datasets/processed/Rat13_SD2_HC_4_posttrial3
# /home/nero/datasets/processed/Rat13_SD2_HC_4_posttrial2
# /home/nero/datasets/processed/Rat13_SD11_OR-N_4_posttrial4
# /home/nero/datasets/processed/Rat13_SD11_OR-N_4_posttrial5
# /home/nero/datasets/processed/Rat13_SD11_OR-N_4_posttrial1
# /home/nero/datasets/processed/Rat13_SD11_OR-N_4_posttrial2
# /home/nero/datasets/processed/Rat13_SD11_OR-N_4_posttrial3
# /home/nero/datasets/processed/Rat13_SD1_CON_4_posttrial1
# /home/nero/datasets/processed/Rat13_SD1_CON_4_posttrial5
# /home/nero/datasets/processed/Rat13_SD1_CON_4_posttrial2
# /home/nero/datasets/processed/Rat13_SD1_CON_4_posttrial3
# /home/nero/datasets/processed/Rat6_SD6_HC_4_posttrial3
# /home/nero/datasets/processed/Rat6_SD6_HC_4_posttrial1
# /home/nero/datasets/processed/Rat6_SD6_HC_4_posttrial2
# /home/nero/datasets/processed/Rat6_SD6_HC_4_posttrial4
# /home/nero/datasets/processed/Rat6_SD6_HC_4_posttrial5
# /home/nero/datasets/processed/Rat6_SD1_HC_4_posttrial2
# /home/nero/datasets/processed/Rat6_SD1_HC_4_posttrial3
# /home/nero/datasets/processed/Rat6_SD1_HC_4_posttrial5
# /home/nero/datasets/processed/Rat6_SD1_HC_4_posttrial4
# /home/nero/datasets/processed/Rat6_SD1_HC_4_posttrial1
# /home/nero/datasets/processed/Rat6_SD10_OD_4_posttrial5
# /home/nero/datasets/processed/Rat6_SD10_OD_4_posttrial3
# /home/nero/datasets/processed/Rat6_SD10_OD_4_posttrial2
# /home/nero/datasets/processed/Rat6_SD10_OD_4_posttrial4
# /home/nero/datasets/processed/Rat6_SD4_CON_4_posttrial1
# /home/nero/datasets/processed/Rat6_SD4_CON_4_posttrial4
# /home/nero/datasets/processed/Rat6_SD4_CON_4_posttrial2
# /home/nero/datasets/processed/Rat6_SD4_CON_4_posttrial5
# /home/nero/datasets/processed/Rat6_SD4_CON_4_posttrial3
# /home/nero/datasets/processed/Rat6_SD7_OR-N_4_posttrial2
# /home/nero/datasets/processed/Rat6_SD7_OR-N_4_posttrial5
# /home/nero/datasets/processed/Rat6_SD7_OR-N_4_posttrial3
# /home/nero/datasets/processed/Rat6_SD7_OR-N_4_posttrial4
# /home/nero/datasets/processed/Rat6_SD3_HC_4_posttrial1
# /home/nero/datasets/processed/Rat6_SD3_HC_4_posttrial4
# /home/nero/datasets/processed/Rat6_SD3_HC_4_posttrial3
# /home/nero/datasets/processed/Rat6_SD3_HC_4_posttrial2
# /home/nero/datasets/processed/Rat6_SD3_HC_4_posttrial5
# /home/nero/datasets/processed/Rat6_SD2_OD_4_posttrial4
# /home/nero/datasets/processed/Rat6_SD2_OD_4_posttrial1
# /home/nero/datasets/processed/Rat6_SD2_OD_4_posttrial3
# /home/nero/datasets/processed/Rat6_SD2_OD_4_posttrial5
# /home/nero/datasets/processed/Rat6_SD2_OD_4_posttrial2
# /home/nero/datasets/processed/Rat6_SD5_OR_4_posttrial1
# /home/nero/datasets/processed/Rat6_SD5_OR_4_posttrial2
# /home/nero/datasets/processed/Rat6_SD5_OR_4_posttrial5
# /home/nero/datasets/processed/Rat6_SD5_OR_4_posttrial4
# /home/nero/datasets/processed/Rat6_SD5_OR_4_posttrial3
# /home/nero/datasets/processed/Rat3_SD3_HC_4_posttrial3
# /home/nero/datasets/processed/Rat3_SD3_HC_4_posttrial5
# /home/nero/datasets/processed/Rat3_SD3_HC_4_posttrial4
# /home/nero/datasets/processed/Rat3_SD2_CON_4_posttrial5
# /home/nero/datasets/processed/Rat3_SD2_CON_4_posttrial4
# /home/nero/datasets/processed/Rat3_SD6_HC_4_posttrial2
# /home/nero/datasets/processed/Rat3_SD6_HC_4_posttrial5
# /home/nero/datasets/processed/Rat3_SD6_HC_4_posttrial3
# /home/nero/datasets/processed/Rat3_SD6_HC_4_posttrial1
# /home/nero/datasets/processed/Rat3_SD6_HC_4_posttrial4
# /home/nero/datasets/processed/Rat3_SD4_OD_4_posttrial3
# /home/nero/datasets/processed/Rat3_SD4_OD_4_posttrial1
# /home/nero/datasets/processed/Rat3_SD4_OD_4_posttrial5
# /home/nero/datasets/processed/Rat3_SD4_OD_4_posttrial4
# /home/nero/datasets/processed/Rat3_SD4_OD_4_posttrial2
# /home/nero/datasets/processed/Rat3_SD5_OR-N_4_posttrial4
# /home/nero/datasets/processed/Rat3_SD5_OR-N_4_posttrial5
# /home/nero/datasets/processed/Rat3_SD1_OR_4_posttrial5
# /home/nero/datasets/processed/Rat3_SD1_OR_4_posttrial4
# /home/nero/datasets/processed/Rat4_SD1_CON_4_posttrial4
# /home/nero/datasets/processed/Rat4_SD1_CON_4_posttrial5
# /home/nero/datasets/processed/Rat4_SD1_CON_4_posttrial3
# /home/nero/datasets/processed/Rat4_SD1_CON_4_posttrial2
# /home/nero/datasets/processed/Rat4_SD3_OR_4_posttrial4
# /home/nero/datasets/processed/Rat4_SD3_OR_4_posttrial5
# /home/nero/datasets/processed/Rat4_SD3_OR_4_posttrial3
# /home/nero/datasets/processed/Rat4_SD6_OD_4_posttrial2
# /home/nero/datasets/processed/Rat4_SD6_OD_4_posttrial4
# /home/nero/datasets/processed/Rat4_SD6_OD_4_posttrial5
# /home/nero/datasets/processed/Rat4_SD6_OD_4_posttrial1
# /home/nero/datasets/processed/Rat4_SD6_OD_4_posttrial3
# /home/nero/datasets/processed/Rat4_SD2_HC_4_posttrial4
# /home/nero/datasets/processed/Rat4_SD2_HC_4_posttrial5
# /home/nero/datasets/processed/Rat4_SD4_OR-N_4_posttrial5
# /home/nero/datasets/processed/Rat4_SD4_OR-N_4_posttrial4
# /home/nero/datasets/processed/Rat11_SD2_OD_4_posttrial1
# /home/nero/datasets/processed/Rat11_SD2_OD_4_posttrial3
# /home/nero/datasets/processed/Rat11_SD2_OD_4_posttrial4
# /home/nero/datasets/processed/Rat11_SD2_OD_4_posttrial2
# /home/nero/datasets/processed/Rat11_SD2_OD_4_posttrial5
# /home/nero/datasets/processed/Rat11_SD3_HC_4_posttrial4
# /home/nero/datasets/processed/Rat11_SD3_HC_4_posttrial1
# /home/nero/datasets/processed/Rat11_SD3_HC_4_posttrial3
# /home/nero/datasets/processed/Rat11_SD3_HC_4_posttrial5
# /home/nero/datasets/processed/Rat11_SD3_HC_4_posttrial2
# /home/nero/datasets/processed/Rat11_SD1_CON_4_posttrial1
# /home/nero/datasets/processed/Rat11_SD1_CON_4_posttrial2
# /home/nero/datasets/processed/Rat11_SD1_CON_4_posttrial3
# /home/nero/datasets/processed/Rat11_SD1_CON_4_posttrial5
# /home/nero/datasets/processed/Rat11_SD1_CON_4_posttrial4
# /home/nero/datasets/processed/Rat11_SD4_OR_4_posttrial1
# /home/nero/datasets/processed/Rat11_SD4_OR_4_posttrial4
# /home/nero/datasets/processed/Rat11_SD4_OR_4_posttrial2
# /home/nero/datasets/processed/Rat11_SD4_OR_4_posttrial5
# /home/nero/datasets/processed/Rat11_SD4_OR_4_posttrial3
